# %% [markdown]
# # ETL
#
# Study of a dataset cotaining various information about 32135 games published on Steam gaming plataform.
#
# | Columna | Descripción | Ejemplo |
# | -- | - | - |
# | publisher | Empresa publicadora del contenido | [Ubisoft,Dovetail Games - Trains,Degica] |
# | genres | Genero del contenido | [Action, Adventure, Racing, Simulation, Strategy] |
# | app_name | Nombre del contenido | [Warzone, Soundtrack, Puzzle Blocks] |
# | title | Titulo del contenido | [The Dream Machine: Chapter 4 , Fate/EXTELLA - Sweet Room Dream, Fate/EXTELLA - Charming Bunny] |
# | url | URL de publicación del contenido | http://store.steampowered.com/app/761140/Lost_Summoner_Kitty/ |
# | release_date | Fecha de lanzamiento | [2018-01-04] |
# | tags | etiquetas de contenido | [Simulation, Indie, Action, Adventure, Funny, Open World, First-Person, Sandbox, Free to Play] |
# | discount_price | precio de descuento | [22.66, 0.49, 0.69] |
# | reviews_url | Reviews de contenido | http://steamcommunity.com/app/681550/reviews/?browsefilter=mostrecent&p=1 |
# | specs | Especificaciones | [Multi-player, Co-op, Cross-Platform Multiplayer, Downloadable Content] |
# | price | Precio del contenido | [4.99, 9.99, Free to Use, Free to Play] |
# | early_access | acceso temprano | [False, True] |
# | id | identificador unico de contenido | [761140, 643980, 670290] |
# | developer | Desarrollador | [Kotoshiro, Secret Level SRL, Poolians.com] |
# | sentiment | Análisis de sentimiento | [Mixed, Very Positive, Positive, 3 user reviews] |
# | metascore | Score por metacritic | [80, 74, 77, 75] |

# %% [markdown]
# Import relevant libraries.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import ast

# %% [markdown]
# ## Read Data

# %% [markdown]
# I tried to open the json file with pd.read_json but i could not do it because of its format.

# %%
# pd.read_json()

# %% [markdown]
# That's why I decided to use "open" and then transform each row into a dictionary.

# %%
# Open file.
file = open('datasets/steam_games.json')

allNewLines = []

# Go through each line 
for line in file:
    # Create a dictionary of each line.
    myNewdict = ast.literal_eval(line)
    # Append to a list of all the lines in the file.
    allNewLines.append(myNewdict)

# %% [markdown]
# With the list of all the rows I can create a DataFrame.

# %%
rawGamesDf = pd.DataFrame(allNewLines)
rawGamesDf.tail(50)
# Out:
#                             publisher
# 32085                             NaN  \
# 32086                 Korovkin Nikita
# 32087  Greyson Richey, Nicholas Lives
# 32088                rechargecomplete
# 32089            Calamity Exploration
# 32090                  Lunarhellgames
# 32091                    Cisamid Inc.
# 32092                     Purpl3Grape
# 32093                    Enkian Games
# 32094                             NaN
# 32095                 Chadams Studios
# 32096                       YAOYICHEN
# 32097             Lunar Giant Studios
# 32098                      Koch Media
# 32099                  Picorinne Soft
# 32100                    杭州分浪网络科技有限公司
# 32101                      KUMA GAMES
# 32102                       BJGameInd
# 32103                           Valve
# 32104                           Valve
# 32105                           Valve
# 32106                           Valve
# 32107                      THQ Nordic
# 32108                           Valve
# 32109                           Valve
# 32110              Spiderweb Software
# 32111                             NaN
# 32112                              2K
# 32113             Topware Interactive
# 32114                           Valve
# 32115              Spiderweb Software
# 32116                Epic Games, Inc.
# 32117                           Valve
# 32118                             NaN
# 32119                             NaN
# 32120                             NaN
# 32121                             NaN
# 32122                       Fred Ells
# 32123                         VersoVR
# 32124                    Phil Fortier
# 32125              Retro Army Limited
# 32126              OrtiGames/OrtiSoft
# 32127                          INGAME
# 32128                        Riviysky
# 32129                 Bidoniera Games
# 32130                 Ghost_RUS Games
# 32131                          Sacada
# 32132                    Laush Studio
# 32133                        SIXNAILS
# 32134                             NaN
#
#                                                   genres
# 32085                                                NaN  \
# 32086           [Action, Adventure, Indie, Early Access]
# 32087                [Action, Casual, Indie, Simulation]
# 32088           [Action, Adventure, Indie, Early Access]
# 32089                           [Action, Adventure, RPG]
# 32090                            [Action, Casual, Indie]
# 32091  [Action, Adventure, Casual, Indie, Massively M...
# 32092                      [Action, Indie, Early Access]
# 32093                            [Adventure, Indie, RPG]
# 32094     [Adventure, Casual, Indie, Simulation, Sports]
# 32095     [Action, Indie, RPG, Simulation, Early Access]
# 32096            [Action, Adventure, Casual, Indie, RPG]
# 32097                                    [Action, Indie]
# 32098                      [Utilities, Video Production]
# 32099                                    [Action, Indie]
# 32100  [Action, Free to Play, Massively Multiplayer, ...
# 32101                                       [Simulation]
# 32102                                            [Indie]
# 32103                                           [Action]
# 32104                                           [Action]
# 32105                                           [Action]
# 32106                                           [Action]
# 32107                                      [Action, RPG]
# 32108                                           [Action]
# 32109                                           [Action]
# 32110                             [Strategy, RPG, Indie]
# 32111                                           [Sports]
# 32112                                [Action, Adventure]
# 32113                            [Action, Casual, Indie]
# 32114                                           [Action]
# 32115                             [Strategy, RPG, Indie]
# 32116                                           [Action]
# 32117                                           [Action]
# 32118                                                NaN
# 32119                                                NaN
# 32120                                                NaN
# 32121                                                NaN
# 32122                                            [Indie]
# 32123  [Casual, Indie, Simulation, Sports, Early Access]
# 32124                                 [Adventure, Indie]
# 32125                         [Action, Adventure, Indie]
# 32126                                    [Casual, Indie]
# 32127                                       [Indie, RPG]
# 32128                                    [Casual, Indie]
# 32129                 [Action, Adventure, Casual, Indie]
# 32130              [Casual, Indie, Simulation, Strategy]
# 32131                          [Casual, Indie, Strategy]
# 32132                        [Indie, Racing, Simulation]
# 32133                                    [Casual, Indie]
# 32134                                                NaN
#
#                                               app_name
# 32085                                       LIV Client  \
# 32086                      SCP-087: Recovered document
# 32087                                 Lonely Astronaut
# 32088                                RECHARGE COMPLETE
# 32089               The 13th Heir - Ragnarok Chapter 2
# 32090                                   Boomer Rampage
# 32091                            PLAYERUNKN4WN: Zombie
# 32092                            TileDynasty FPS Arena
# 32093                           Ender Story: Chapter 1
# 32094                Casino Slot Machines - The Spring
# 32095                        BlockShip Wars: Roguelike
# 32096                                PearsAndGrayWitch
# 32097                                       Tetrapulse
# 32098                        CyberLink YouCam 7 Deluxe
# 32099                                   Infinos Gaiden
# 32100                                           忍者村大战2
# 32101                            High School Simulator
# 32102                                         NeoBalls
# 32103                            Team Fortress Classic
# 32104                        Half-Life: Opposing Force
# 32105                                         Ricochet
# 32106                                   Counter-Strike
# 32107                                         Gothic 1
# 32108                               Deathmatch Classic
# 32109                            Half-Life: Blue Shift
# 32110                                      Geneforge 1
# 32111                      International Online Soccer
# 32112                                            Mafia
# 32113                               Chicken Shoot Gold
# 32114                                    Day of Defeat
# 32115                                      Geneforge 2
# 32116  Unreal Tournament 2004: Editor's Choice Edition
# 32117                   Counter-Strike: Condition Zero
# 32118        Robotpencil Presents: Exercise: Brushwork
# 32119       Robotpencil Presents: Creative Composition
# 32120                                 The Gamble House
# 32121         Kalen Chock Presents: 2017 Free Tutorial
# 32122                          Agent X: Equation Rider
# 32123                                     Cricket Club
# 32124               Snail Trek - Chapter 3: Lettuce Be
# 32125                             The spy who shot me™
# 32126                                   Raining blocks
# 32127                                          Bravium
# 32128                                            BAE 2
# 32129                                     Kebab it Up!
# 32130                                   Colony On Mars
# 32131                         LOGistICAL: South Africa
# 32132                                    Russian Roads
# 32133                              EXIT 2 - Directions
# 32134                                      Maze Run VR
#
#                                                  title
# 32085                                              NaN  \
# 32086                      SCP-087: Recovered document
# 32087                                 Lonely Astronaut
# 32088                                RECHARGE COMPLETE
# 32089               The 13th Heir - Ragnarok Chapter 2
# 32090                                   Boomer Rampage
# 32091                            PLAYERUNKN4WN: Zombie
# 32092                            TileDynasty FPS Arena
# 32093                           Ender Story: Chapter 1
# 32094                Casino Slot Machines - The Spring
# 32095                        BlockShip Wars: Roguelike
# 32096                                PearsAndGrayWitch
# 32097                                       Tetrapulse
# 32098                        CyberLink YouCam 7 Deluxe
# 32099                                   Infinos Gaiden
# 32100                                           忍者村大战2
# 32101                            High School Simulator
# 32102                                         NeoBalls
# 32103                            Team Fortress Classic
# 32104                        Half-Life: Opposing Force
# 32105                                         Ricochet
# 32106                                   Counter-Strike
# 32107                                         Gothic 1
# 32108                               Deathmatch Classic
# 32109                            Half-Life: Blue Shift
# 32110                                      Geneforge 1
# 32111                      International Online Soccer
# 32112                                            Mafia
# 32113                               Chicken Shoot Gold
# 32114                                    Day of Defeat
# 32115                                      Geneforge 2
# 32116  Unreal Tournament 2004: Editor's Choice Edition
# 32117                   Counter-Strike: Condition Zero
# 32118        Robotpencil Presents: Exercise: Brushwork
# 32119       Robotpencil Presents: Creative Composition
# 32120                                 The Gamble House
# 32121         Kalen Chock Presents: 2017 Free Tutorial
# 32122                          Agent X: Equation Rider
# 32123                                     Cricket Club
# 32124               Snail Trek - Chapter 3: Lettuce Be
# 32125                             The spy who shot me™
# 32126                                   Raining blocks
# 32127                                          Bravium
# 32128                                            BAE 2
# 32129                                     Kebab it Up!
# 32130                                   Colony On Mars
# 32131                         LOGistICAL: South Africa
# 32132                                    Russian Roads
# 32133                              EXIT 2 - Directions
# 32134                                              NaN
#
#                                                      url  release_date
# 32085  http://store.steampowered.com/app/755540/LIV_C...           NaN  \
# 32086  http://store.steampowered.com/app/765180/SCP08...    2018-01-01
# 32087  http://store.steampowered.com/app/755830/Lonel...   Coming Soon
# 32088  http://store.steampowered.com/app/708070/RECHA...           NaN
# 32089  http://store.steampowered.com/app/759900/The_1...    2017-12-20
# 32090  http://store.steampowered.com/app/770520/Boome...    2018-01-01
# 32091  http://store.steampowered.com/app/737750/PLAYE...    2018-01-01
# 32092  http://store.steampowered.com/app/524350/TileD...    2018-01-01
# 32093  http://store.steampowered.com/app/760300/Ender...    2018-01-01
# 32094  http://store.steampowered.com/app/776420/Casin...    2018-01-01
# 32095  http://store.steampowered.com/app/763320/Block...    2018-01-01
# 32096  http://store.steampowered.com/app/766700/Pears...    2018-01-01
# 32097  http://store.steampowered.com/app/250440/Tetra...          2016
# 32098  http://store.steampowered.com/app/755310/Cyber...    2017-12-26
# 32099  http://store.steampowered.com/app/771070/Infin...    2018-01-19
# 32100        http://store.steampowered.com/app/754350/2/    2018-01-03
# 32101  http://store.steampowered.com/app/754620/High_...    2018-01-03
# 32102  http://store.steampowered.com/app/771610/NeoBa...    2018-01-03
# 32103  http://store.steampowered.com/app/20/Team_Fort...    1999-04-01
# 32104  http://store.steampowered.com/app/50/HalfLife_...    1999-11-01
# 32105     http://store.steampowered.com/app/60/Ricochet/    2000-11-01
# 32106  http://store.steampowered.com/app/10/CounterSt...    2000-11-01
# 32107  http://store.steampowered.com/app/65540/Gothic_1/    2001-03-15
# 32108  http://store.steampowered.com/app/40/Deathmatc...    2001-06-01
# 32109  http://store.steampowered.com/app/130/HalfLife...    2001-06-01
# 32110  http://store.steampowered.com/app/200960/Genef...    2001-12-01
# 32111  http://store.steampowered.com/app/90007/Intern...    2002-01-01
# 32112     http://store.steampowered.com/app/40990/Mafia/    2002-08-28
# 32113  http://store.steampowered.com/app/259340/Chick...    2003-11-01
# 32114  http://store.steampowered.com/app/30/Day_of_De...    2003-05-01
# 32115  http://store.steampowered.com/app/200980/Genef...    2003-07-01
# 32116  http://store.steampowered.com/app/13230/Unreal...    2004-03-16
# 32117  http://store.steampowered.com/app/80/CounterSt...    2004-03-01
# 32118  http://store.steampowered.com/app/775640/Robot...    2018-01-03
# 32119  http://store.steampowered.com/app/777930/Robot...    2018-01-03
# 32120  http://store.steampowered.com/app/775370/The_G...    2016-11-19
# 32121  http://store.steampowered.com/app/777950/Kalen...    2018-01-03
# 32122  http://store.steampowered.com/app/767010/Agent...    2018-01-03
# 32123  http://store.steampowered.com/app/772180/Crick...  January 2018
# 32124  http://store.steampowered.com/app/761480/Snail...    2018-01-03
# 32125  http://store.steampowered.com/app/771810/The_s...    2018-10-01
# 32126  http://store.steampowered.com/app/767590/Raini...    2018-01-04
# 32127  http://store.steampowered.com/app/747320/Bravium/    2018-01-04
# 32128    http://store.steampowered.com/app/769330/BAE_2/    2018-01-04
# 32129  http://store.steampowered.com/app/745400/Kebab...    2018-01-04
# 32130  http://store.steampowered.com/app/773640/Colon...    2018-01-04
# 32131  http://store.steampowered.com/app/733530/LOGis...    2018-01-04
# 32132  http://store.steampowered.com/app/610660/Russi...    2018-01-04
# 32133  http://store.steampowered.com/app/658870/EXIT_...    2017-09-02
# 32134  http://store.steampowered.com/app/681550/Maze_...           NaN
#
#                                                     tags  discount_price
# 32085      [Video Production, Utilities, Web Publishing]             NaN  \
# 32086  [Early Access, Indie, Action, Adventure, Horro...             NaN
# 32087                [Casual, Action, Indie, Simulation]             NaN
# 32088           [Early Access, Action, Adventure, Indie]             NaN
# 32089                 [Action, Adventure, RPG, RPGMaker]             NaN
# 32090                            [Action, Casual, Indie]            0.89
# 32091  [Action, Adventure, Massively Multiplayer, Cas...             NaN
# 32092       [Early Access, Action, Indie, Arena Shooter]            4.68
# 32093                  [Adventure, RPG, Indie, RPGMaker]            0.69
# 32094     [Adventure, Indie, Casual, Simulation, Sports]            0.79
# 32095     [Early Access, Action, Indie, Simulation, RPG]           11.69
# 32096            [Action, Adventure, Casual, Indie, RPG]             NaN
# 32097                             [Indie, Action, Co-op]             NaN
# 32098                      [Utilities, Video Production]           25.49
# 32099                      [Action, Indie, Shoot 'Em Up]             NaN
# 32100  [Free to Play, Strategy, Action, Massively Mul...             NaN
# 32101  [Simulation, Sexual Content, Gore, Violent, An...             NaN
# 32102                                            [Indie]            0.89
# 32103  [Action, FPS, Multiplayer, Classic, Shooter, C...             NaN
# 32104  [FPS, Action, Sci-fi, Singleplayer, Classic, S...             NaN
# 32105  [Action, FPS, Multiplayer, First-Person, Cyber...             NaN
# 32106  [Action, FPS, Multiplayer, Shooter, Classic, T...             NaN
# 32107  [RPG, Atmospheric, Open World, Classic, Fantas...             NaN
# 32108  [Action, FPS, Multiplayer, Classic, Shooter, F...             NaN
# 32109  [FPS, Action, Sci-fi, Singleplayer, Shooter, A...             NaN
# 32110  [RPG, Indie, Strategy, Isometric, Turn-Based C...             NaN
# 32111                                      [Sports, Mod]             NaN
# 32112  [Action, Adventure, Violent, Story Rich, Class...             NaN
# 32113                   [Action, Casual, Indie, Shooter]             NaN
# 32114  [FPS, World War II, Multiplayer, Action, Shoot...             NaN
# 32115  [RPG, Indie, Strategy, Turn-Based Combat, Isom...             NaN
# 32116  [FPS, Arena Shooter, Action, Classic, Multipla...             NaN
# 32117  [Action, FPS, Shooter, Multiplayer, Singleplay...             NaN
# 32118                  [Design & Illustration, Tutorial]             NaN
# 32119                  [Design & Illustration, Tutorial]             NaN
# 32120                                            [Movie]             NaN
# 32121                  [Design & Illustration, Tutorial]             NaN
# 32122                                            [Indie]             NaN
# 32123  [Early Access, Indie, Casual, Simulation, Sports]             NaN
# 32124  [Adventure, Indie, Retro, Point & Click, Pixel...            0.84
# 32125                         [Action, Adventure, Indie]             NaN
# 32126                                    [Indie, Casual]             NaN
# 32127                [Indie, RPG, Puzzle, Tower Defense]           11.99
# 32128                                    [Indie, Casual]             NaN
# 32129        [Action, Indie, Casual, Violent, Adventure]            1.69
# 32130              [Strategy, Indie, Casual, Simulation]            1.49
# 32131                          [Strategy, Indie, Casual]            4.24
# 32132                        [Indie, Simulation, Racing]            1.39
# 32133  [Indie, Casual, Puzzle, Singleplayer, Atmosphe...             NaN
# 32134  [Early Access, Adventure, Indie, Action, Simul...             NaN
#
#                                              reviews_url
# 32085  http://steamcommunity.com/app/755540/reviews/?...  \
# 32086  http://steamcommunity.com/app/765180/reviews/?...
# 32087  http://steamcommunity.com/app/755830/reviews/?...
# 32088  http://steamcommunity.com/app/708070/reviews/?...
# 32089  http://steamcommunity.com/app/759900/reviews/?...
# 32090  http://steamcommunity.com/app/770520/reviews/?...
# 32091  http://steamcommunity.com/app/737750/reviews/?...
# 32092  http://steamcommunity.com/app/524350/reviews/?...
# 32093  http://steamcommunity.com/app/760300/reviews/?...
# 32094  http://steamcommunity.com/app/776420/reviews/?...
# 32095  http://steamcommunity.com/app/763320/reviews/?...
# 32096  http://steamcommunity.com/app/766700/reviews/?...
# 32097  http://steamcommunity.com/app/250440/reviews/?...
# 32098  http://steamcommunity.com/app/755310/reviews/?...
# 32099  http://steamcommunity.com/app/771070/reviews/?...
# 32100  http://steamcommunity.com/app/754350/reviews/?...
# 32101  http://steamcommunity.com/app/754620/reviews/?...
# 32102  http://steamcommunity.com/app/771610/reviews/?...
# 32103  http://steamcommunity.com/app/20/reviews/?brow...
# 32104  http://steamcommunity.com/app/50/reviews/?brow...
# 32105  http://steamcommunity.com/app/60/reviews/?brow...
# 32106  http://steamcommunity.com/app/10/reviews/?brow...
# 32107  http://steamcommunity.com/app/65540/reviews/?b...
# 32108  http://steamcommunity.com/app/40/reviews/?brow...
# 32109  http://steamcommunity.com/app/130/reviews/?bro...
# 32110  http://steamcommunity.com/app/200960/reviews/?...
# 32111  http://steamcommunity.com/app/90007/reviews/?b...
# 32112  http://steamcommunity.com/app/40990/reviews/?b...
# 32113  http://steamcommunity.com/app/259340/reviews/?...
# 32114  http://steamcommunity.com/app/30/reviews/?brow...
# 32115  http://steamcommunity.com/app/200980/reviews/?...
# 32116  http://steamcommunity.com/app/13230/reviews/?b...
# 32117  http://steamcommunity.com/app/80/reviews/?brow...
# 32118  http://steamcommunity.com/app/775640/reviews/?...
# 32119  http://steamcommunity.com/app/777930/reviews/?...
# 32120  http://steamcommunity.com/app/775370/reviews/?...
# 32121  http://steamcommunity.com/app/777950/reviews/?...
# 32122  http://steamcommunity.com/app/767010/reviews/?...
# 32123  http://steamcommunity.com/app/772180/reviews/?...
# 32124  http://steamcommunity.com/app/761480/reviews/?...
# 32125  http://steamcommunity.com/app/771810/reviews/?...
# 32126  http://steamcommunity.com/app/767590/reviews/?...
# 32127  http://steamcommunity.com/app/747320/reviews/?...
# 32128  http://steamcommunity.com/app/769330/reviews/?...
# 32129  http://steamcommunity.com/app/745400/reviews/?...
# 32130  http://steamcommunity.com/app/773640/reviews/?...
# 32131  http://steamcommunity.com/app/733530/reviews/?...
# 32132  http://steamcommunity.com/app/610660/reviews/?...
# 32133  http://steamcommunity.com/app/658870/reviews/?...
# 32134  http://steamcommunity.com/app/681550/reviews/?...
#
#                                                    specs         price
# 32085  [Steam Workshop, Steam Cloud, HTC Vive, Oculus...           NaN  \
# 32086                                    [Single-player]          9.99
# 32087                                    [Single-player]           NaN
# 32088                [Single-player, Steam Achievements]           NaN
# 32089                [Single-player, Steam Achievements]           NaN
# 32090  [Single-player, Steam Achievements, Steam Clou...          0.99
# 32091                [Single-player, Steam Achievements]          0.99
# 32092  [Single-player, Multi-player, Online Multi-Pla...          6.99
# 32093           [Single-player, Full controller support]          0.99
# 32094              [Single-player, Downloadable Content]          0.99
# 32095                                    [Single-player]         12.99
# 32096                                    [Single-player]          4.99
# 32097  [Multi-player, Co-op, Shared/Split Screen, Ste...           NaN
# 32098                                                NaN         29.99
# 32099        [Single-player, Partial Controller Support]           NaN
# 32100            [Online Multi-Player, In-App Purchases]  Free To Play
# 32101        [Single-player, Partial Controller Support]          Free
# 32102  [Single-player, Steam Achievements, Steam Trad...          0.99
# 32103           [Multi-player, Valve Anti-Cheat enabled]          4.99
# 32104  [Single-player, Multi-player, Valve Anti-Cheat...          4.99
# 32105           [Multi-player, Valve Anti-Cheat enabled]          4.99
# 32106           [Multi-player, Valve Anti-Cheat enabled]          9.99
# 32107                                    [Single-player]         19.99
# 32108           [Multi-player, Valve Anti-Cheat enabled]          4.99
# 32109                                    [Single-player]          4.99
# 32110                                    [Single-player]         19.99
# 32111                 [Multi-player, Mods (require HL2)]           NaN
# 32112                                    [Single-player]         14.99
# 32113  [Single-player, Multi-player, Steam Trading Ca...          6.99
# 32114           [Multi-player, Valve Anti-Cheat enabled]          4.99
# 32115                                    [Single-player]         19.99
# 32116  [Single-player, Multi-player, Steam Trading Ca...         14.99
# 32117  [Single-player, Multi-player, Valve Anti-Cheat...          9.99
# 32118                                                NaN          3.99
# 32119                                                NaN          3.99
# 32120                               [Captions available]          4.99
# 32121                                                NaN          Free
# 32122                                    [Single-player]          3.99
# 32123                                    [Single-player]           NaN
# 32124                [Single-player, Steam Achievements]          0.99
# 32125                [Single-player, Captions available]           NaN
# 32126  [Single-player, Shared/Split Screen, Steam Ach...          0.99
# 32127  [Single-player, Steam Achievements, Steam Lead...         14.99
# 32128                                    [Single-player]           NaN
# 32129   [Single-player, Steam Achievements, Steam Cloud]          1.99
# 32130                [Single-player, Steam Achievements]          1.99
# 32131  [Single-player, Steam Achievements, Steam Clou...          4.99
# 32132  [Single-player, Steam Achievements, Steam Trad...          1.99
# 32133   [Single-player, Steam Achievements, Steam Cloud]          4.99
# 32134  [Single-player, Stats, Steam Leaderboards, HTC...          4.99
#
#        early_access      id
# 32085         False  755540  \
# 32086          True  765180
# 32087         False  755830
# 32088          True  708070
# 32089         False  759900
# 32090         False  770520
# 32091         False  737750
# 32092          True  524350
# 32093         False  760300
# 32094         False  776420
# 32095          True  763320
# 32096         False  766700
# 32097         False  250440
# 32098         False  755310
# 32099         False  771070
# 32100         False  754350
# 32101         False  754620
# 32102         False  771610
# 32103         False      20
# 32104         False      50
# 32105         False      60
# 32106         False      10
# 32107         False   65540
# 32108         False      40
# 32109         False     130
# 32110         False  200960
# 32111         False   90007
# 32112         False   40990
# 32113         False  259340
# 32114         False      30
# 32115         False  200980
# 32116         False   13230
# 32117         False      80
# 32118         False  775640
# 32119         False  777930
# 32120         False  775370
# 32121         False  777950
# 32122         False  767010
# 32123          True  772180
# 32124         False  761480
# 32125         False  771810
# 32126         False  767590
# 32127         False  747320
# 32128         False  769330
# 32129         False  745400
# 32130         False  773640
# 32131         False  733530
# 32132         False  610660
# 32133         False  658870
# 32134          True  681550
#
#                                                developer
# 32085                                                NaN  \
# 32086  Korovkin Nikita,Filatov Igor,Lagunov Roman,Kri...
# 32087                      Greyson Richey,Nicholas Lives
# 32088                                   rechargecomplete
# 32089                              Samuel James Swartout
# 32090                                     Lunarhellgames
# 32091                                lalalaZero,Urbanoff
# 32092                                        Purpl3Grape
# 32093                                       Enkian Games
# 32094                                 Boogygames Studios
# 32095                                    Chadams Studios
# 32096                                          YAOYICHEN
# 32097                                        The Amiable
# 32098                                          CyberLink
# 32099                                     Picorinne Soft
# 32100                                       杭州分浪网络科技有限公司
# 32101                                         KUMA GAMES
# 32102                                          BJGameInd
# 32103                                              Valve
# 32104                                   Gearbox Software
# 32105                                              Valve
# 32106                                              Valve
# 32107                                      Piranha Bytes
# 32108                                              Valve
# 32109                                   Gearbox Software
# 32110                                 Spiderweb Software
# 32111                                        I.O.S. Team
# 32112                                 Illusion Softworks
# 32113                                  ToonTRAXX Studios
# 32114                                              Valve
# 32115                                 Spiderweb Software
# 32116                                   Epic Games, Inc.
# 32117                                              Valve
# 32118                                                NaN
# 32119                                                NaN
# 32120                                                NaN
# 32121                                                NaN
# 32122                                          Fred Ells
# 32123                                            VersoVR
# 32124                                       Phil Fortier
# 32125                                 Retro Army Limited
# 32126          Oscar Ortigueira López,OrtiGames/OrtiSoft
# 32127                                             INGAME
# 32128                                           Riviysky
# 32129                                    Bidoniera Games
# 32130                                 Nikita "Ghost_RUS"
# 32131                                             Sacada
# 32132                           Laush Dmitriy Sergeevich
# 32133                                      xropi,stev3ns
# 32134                                                NaN
#
#                      sentiment metascore
# 32085                      NaN       NaN
# 32086           9 user reviews       NaN
# 32087                      NaN       NaN
# 32088                      NaN       NaN
# 32089                      NaN       NaN
# 32090                      NaN       NaN
# 32091          Mostly Negative       NaN
# 32092           1 user reviews       NaN
# 32093           1 user reviews       NaN
# 32094                      NaN       NaN
# 32095                      NaN       NaN
# 32096           7 user reviews       NaN
# 32097                      NaN       NaN
# 32098                      NaN       NaN
# 32099                      NaN       NaN
# 32100                    Mixed       NaN
# 32101                    Mixed       NaN
# 32102                      NaN       NaN
# 32103            Very Positive       NaN
# 32104            Very Positive       NaN
# 32105          Mostly Positive       NaN
# 32106  Overwhelmingly Positive        88
# 32107            Very Positive        81
# 32108            Very Positive       NaN
# 32109            Very Positive        71
# 32110            Very Positive       NaN
# 32111                      NaN       NaN
# 32112  Overwhelmingly Positive        88
# 32113                    Mixed       NaN
# 32114            Very Positive        79
# 32115                 Positive       NaN
# 32116  Overwhelmingly Positive        93
# 32117            Very Positive        65
# 32118                      NaN       NaN
# 32119                      NaN       NaN
# 32120                      NaN       NaN
# 32121                      NaN       NaN
# 32122                      NaN       NaN
# 32123                      NaN       NaN
# 32124           4 user reviews       NaN
# 32125                      NaN       NaN
# 32126           1 user reviews       NaN
# 32127           3 user reviews       NaN
# 32128                      NaN       NaN
# 32129           2 user reviews       NaN
# 32130                      NaN       NaN
# 32131                      NaN       NaN
# 32132                      NaN       NaN
# 32133           1 user reviews       NaN
# 32134                 Positive       NaN

# %%
rawGamesDf['release_date'].tail(50).str.contains('2018').value_counts()
# Out:
# release_date
# True     26
# False    21
# Name: count, dtype: int64

# %% [markdown]
# ## Columns: url & reviews_url
# We do not need any url for the analysis so we will drop them.

# %%
rawGamesDf.drop(columns=['url', 'reviews_url'], inplace=True)

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# # WHAT TYPE OF DATA FILE TO USE???????????

# %% [markdown]
# ## Export to csv

# %%
rawGamesDf.to_json("datasets/steam_games_format_ok.json")

# %% [markdown]
# ---

# %% [markdown]
# ## CREATE API FUNCTIONS (Testing)

# %%
def read_steam_games_data():
    """
    Reads steam_games_format_ok.json and returns a dataframe.
    """
    return pd.read_json("datasets/steam_games_format_ok.json")

# %%
# Read data.
df = read_steam_games_data()
df.head(2)
# Out:
#           publisher                                         genres
# 0         Kotoshiro  [Action, Casual, Indie, Simulation, Strategy]  \
# 1  Making Fun, Inc.           [Free to Play, Indie, RPG, Strategy]
#
#               app_name                title release_date
# 0  Lost Summoner Kitty  Lost Summoner Kitty   2018-01-04  \
# 1            Ironbound            Ironbound   2018-01-04
#
#                                                 tags  discount_price
# 0      [Strategy, Action, Indie, Casual, Simulation]            4.49  \
# 1  [Free to Play, Strategy, Indie, RPG, Card Game...             NaN
#
#                                                specs         price
# 0                                    [Single-player]          4.99  \
# 1  [Single-player, Multi-player, Online Multi-Pla...  Free To Play
#
#    early_access        id         developer        sentiment metascore
# 0         False  761140.0         Kotoshiro             None      None
# 1         False  643980.0  Secret Level SRL  Mostly Positive      None

# %%
year = 2018
# Se ingresa un año y devuelve un diccionario con los 5 géneros más vendidos en el orden correspondiente.

# %%
genresCompleteList = df.explode(column=['genres'])['genres'].unique()
print(genresCompleteList)
print(genresCompleteList.shape)
# Out:
# ['Action' 'Casual' 'Indie' 'Simulation' 'Strategy' 'Free to Play' 'RPG'
#  'Sports' 'Adventure' None 'Racing' 'Early Access' 'Massively Multiplayer'
#  'Animation &amp; Modeling' 'Video Production' 'Utilities'
#  'Web Publishing' 'Education' 'Software Training'
#  'Design &amp; Illustration' 'Audio Production' 'Photo Editing'
#  'Accounting']
# (23,)

# %%
df.shape
# Out:
# (32135, 14)

# %%
df = df.explode('genres')
df.head()
# Out:
#    publisher      genres             app_name                title
# 0  Kotoshiro      Action  Lost Summoner Kitty  Lost Summoner Kitty  \
# 0  Kotoshiro      Casual  Lost Summoner Kitty  Lost Summoner Kitty
# 0  Kotoshiro       Indie  Lost Summoner Kitty  Lost Summoner Kitty
# 0  Kotoshiro  Simulation  Lost Summoner Kitty  Lost Summoner Kitty
# 0  Kotoshiro    Strategy  Lost Summoner Kitty  Lost Summoner Kitty
#
#   release_date                                           tags  discount_price
# 0   2018-01-04  [Strategy, Action, Indie, Casual, Simulation]            4.49  \
# 0   2018-01-04  [Strategy, Action, Indie, Casual, Simulation]            4.49
# 0   2018-01-04  [Strategy, Action, Indie, Casual, Simulation]            4.49
# 0   2018-01-04  [Strategy, Action, Indie, Casual, Simulation]            4.49
# 0   2018-01-04  [Strategy, Action, Indie, Casual, Simulation]            4.49
#
#              specs price  early_access        id  developer sentiment
# 0  [Single-player]  4.99         False  761140.0  Kotoshiro      None  \
# 0  [Single-player]  4.99         False  761140.0  Kotoshiro      None
# 0  [Single-player]  4.99         False  761140.0  Kotoshiro      None
# 0  [Single-player]  4.99         False  761140.0  Kotoshiro      None
# 0  [Single-player]  4.99         False  761140.0  Kotoshiro      None
#
#   metascore
# 0      None
# 0      None
# 0      None
# 0      None
# 0      None

# %%
df.shape
# Out:
# (74837, 14)

# %%
# Filter release date to the year asked by parameter.
df = df[df['release_date'].str.contains(str(year), na=False)]
df.head(10)
# Out:
#              publisher        genres               app_name
# 0            Kotoshiro        Action    Lost Summoner Kitty  \
# 0            Kotoshiro        Casual    Lost Summoner Kitty
# 0            Kotoshiro         Indie    Lost Summoner Kitty
# 0            Kotoshiro    Simulation    Lost Summoner Kitty
# 0            Kotoshiro      Strategy    Lost Summoner Kitty
# 1     Making Fun, Inc.  Free to Play              Ironbound
# 1     Making Fun, Inc.         Indie              Ironbound
# 1     Making Fun, Inc.           RPG              Ironbound
# 1     Making Fun, Inc.      Strategy              Ironbound
# 5  Trickjump Games Ltd        Action  Battle Royale Trainer
#
#                    title release_date
# 0    Lost Summoner Kitty   2018-01-04  \
# 0    Lost Summoner Kitty   2018-01-04
# 0    Lost Summoner Kitty   2018-01-04
# 0    Lost Summoner Kitty   2018-01-04
# 0    Lost Summoner Kitty   2018-01-04
# 1              Ironbound   2018-01-04
# 1              Ironbound   2018-01-04
# 1              Ironbound   2018-01-04
# 1              Ironbound   2018-01-04
# 5  Battle Royale Trainer   2018-01-04
#
#                                                 tags  discount_price
# 0      [Strategy, Action, Indie, Casual, Simulation]            4.49  \
# 0      [Strategy, Action, Indie, Casual, Simulation]            4.49
# 0      [Strategy, Action, Indie, Casual, Simulation]            4.49
# 0      [Strategy, Action, Indie, Casual, Simulation]            4.49
# 0      [Strategy, Action, Indie, Casual, Simulation]            4.49
# 1  [Free to Play, Strategy, Indie, RPG, Card Game...             NaN
# 1  [Free to Play, Strategy, Indie, RPG, Card Game...             NaN
# 1  [Free to Play, Strategy, Indie, RPG, Card Game...             NaN
# 1  [Free to Play, Strategy, Indie, RPG, Card Game...             NaN
# 5  [Action, Adventure, Simulation, FPS, Shooter, ...             NaN
#
#                                                specs         price
# 0                                    [Single-player]          4.99  \
# 0                                    [Single-player]          4.99
# 0                                    [Single-player]          4.99
# 0                                    [Single-player]          4.99
# 0                                    [Single-player]          4.99
# 1  [Single-player, Multi-player, Online Multi-Pla...  Free To Play
# 1  [Single-player, Multi-player, Online Multi-Pla...  Free To Play
# 1  [Single-player, Multi-player, Online Multi-Pla...  Free To Play
# 1  [Single-player, Multi-player, Online Multi-Pla...  Free To Play
# 5                [Single-player, Steam Achievements]          3.99
#
#    early_access        id            developer        sentiment metascore
# 0         False  761140.0            Kotoshiro             None      None
# 0         False  761140.0            Kotoshiro             None      None
# 0         False  761140.0            Kotoshiro             None      None
# 0         False  761140.0            Kotoshiro             None      None
# 0         False  761140.0            Kotoshiro             None      None
# 1         False  643980.0     Secret Level SRL  Mostly Positive      None
# 1         False  643980.0     Secret Level SRL  Mostly Positive      None
# 1         False  643980.0     Secret Level SRL  Mostly Positive      None
# 1         False  643980.0     Secret Level SRL  Mostly Positive      None
# 5         False  772540.0  Trickjump Games Ltd            Mixed      None

# %%
df.shape
# Out:
# (503, 14)

# %%
df['genres'].value_counts()[0:5].to_dict()
# Out:
# {'Indie': 125, 'Action': 75, 'Adventure': 74, 'Casual': 45, 'Simulation': 43}

# %%
def genero(Year: str): 
    """
    Se ingresa un año y devuelve un diccionario con los 5 géneros más vendidos en el orden correspondiente.
    
    return DICTIONARY?
    """
    # Read data
    df = read_steam_games_data()
    # Since the genres column are list we need to explode it to count each genre.
    df = df.explode('genres')
    # Filter by the parameter year.
    df = df[df['release_date'].str.contains(Year, na=False)]
    # Get top 5 
    top5 = df['genres'].value_counts()[0:5].to_dict()

    return top5

genero('2016')
# Out:
# {'Indie': 4106,
#  'Action': 2544,
#  'Casual': 2141,
#  'Adventure': 2042,
#  'Simulation': 1666}
