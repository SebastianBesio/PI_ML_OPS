# %% [markdown]
# # PREPROCESSING
#
# Study of a dataset cotaining various information about 32135 games published on Steam gaming plataform.
#
# | Columna | Descripción | Ejemplo |
# | -- | - | - |
# | publisher | Empresa publicadora del contenido | [Ubisoft,Dovetail Games - Trains,Degica] |
# | genres | Genero del contenido | [Action, Adventure, Racing, Simulation, Strategy] |
# | app_name | Nombre del contenido | [Warzone, Soundtrack, Puzzle Blocks] |
# | title | Titulo del contenido | [The Dream Machine: Chapter 4 , Fate/EXTELLA - Sweet Room Dream, Fate/EXTELLA - Charming Bunny] |
# | url | URL de publicación del contenido | http://store.steampowered.com/app/761140/Lost_Summoner_Kitty/ |
# | release_date | Fecha de lanzamiento | [2018-01-04] |
# | tags | etiquetas de contenido | [Simulation, Indie, Action, Adventure, Funny, Open World, First-Person, Sandbox, Free to Play] |
# | discount_price | precio de descuento | [22.66, 0.49, 0.69] |
# | reviews_url | Reviews de contenido | http://steamcommunity.com/app/681550/reviews/?browsefilter=mostrecent&p=1 |
# | specs | Especificaciones | [Multi-player, Co-op, Cross-Platform Multiplayer, Downloadable Content] |
# | price | Precio del contenido | [4.99, 9.99, Free to Use, Free to Play] |
# | early_access | acceso temprano | [False, True] |
# | id | identificador unico de contenido | [761140, 643980, 670290] |
# | developer | Desarrollador | [Kotoshiro, Secret Level SRL, Poolians.com] |
# | sentiment | Análisis de sentimiento | [Mixed, Very Positive, Positive, 3 user reviews] |
# | metascore | Score por metacritic | [80, 74, 77, 75] |

# %% [markdown]
# Import relevant libraries.

# %%
import pandas as pd
import numpy as np
import ast
import json

# %% [markdown]
# ## Read Data

# %% [markdown]
# I tried to open the json file with pd.read_json but i could not do it because of it's format.

# %%
# pd.read_json()

# %% [markdown]
# That's why I decided to use "open" and then transform each row into a dictionary. With the list of all the rows I can create a DataFrame.

# %%
# Open file.
file = open('datasets/steam_games.json')

allNewLines = []

# Go through each line 
for line in file:
    # Create a dictionary of each line.
    myNewdict = ast.literal_eval(line)
    # Append to a list of all the lines in the file.
    allNewLines.append(myNewdict)

rawGamesDf = pd.DataFrame(allNewLines)

# %%
rawGamesDf.head(2)
# Out:
#           publisher                                         genres
# 0         Kotoshiro  [Action, Casual, Indie, Simulation, Strategy]  \
# 1  Making Fun, Inc.           [Free to Play, Indie, RPG, Strategy]
#
#               app_name                title
# 0  Lost Summoner Kitty  Lost Summoner Kitty  \
# 1            Ironbound            Ironbound
#
#                                                  url release_date
# 0  http://store.steampowered.com/app/761140/Lost_...   2018-01-04  \
# 1  http://store.steampowered.com/app/643980/Ironb...   2018-01-04
#
#                                                 tags  discount_price
# 0      [Strategy, Action, Indie, Casual, Simulation]            4.49  \
# 1  [Free to Play, Strategy, Indie, RPG, Card Game...             NaN
#
#                                          reviews_url
# 0  http://steamcommunity.com/app/761140/reviews/?...  \
# 1  http://steamcommunity.com/app/643980/reviews/?...
#
#                                                specs         price
# 0                                    [Single-player]          4.99  \
# 1  [Single-player, Multi-player, Online Multi-Pla...  Free To Play
#
#    early_access      id         developer        sentiment metascore
# 0         False  761140         Kotoshiro              NaN       NaN
# 1         False  643980  Secret Level SRL  Mostly Positive       NaN

# %% [markdown]
# ## Columns: url & reviews_url
# We do not need any url for the analysis so we will drop them.

# %%
rawGamesDf.drop(columns=['url', 'reviews_url'], inplace=True)

# %%
rawGamesDf.head(2)
# Out:
#           publisher                                         genres
# 0         Kotoshiro  [Action, Casual, Indie, Simulation, Strategy]  \
# 1  Making Fun, Inc.           [Free to Play, Indie, RPG, Strategy]
#
#               app_name                title release_date
# 0  Lost Summoner Kitty  Lost Summoner Kitty   2018-01-04  \
# 1            Ironbound            Ironbound   2018-01-04
#
#                                                 tags  discount_price
# 0      [Strategy, Action, Indie, Casual, Simulation]            4.49  \
# 1  [Free to Play, Strategy, Indie, RPG, Card Game...             NaN
#
#                                                specs         price
# 0                                    [Single-player]          4.99  \
# 1  [Single-player, Multi-player, Online Multi-Pla...  Free To Play
#
#    early_access      id         developer        sentiment metascore
# 0         False  761140         Kotoshiro              NaN       NaN
# 1         False  643980  Secret Level SRL  Mostly Positive       NaN

# %% [markdown]
# ---

# %% [markdown]
# ## Duplicates
#
# Analysis if there are duplicates

# %%
# Games with duplicate ids, dropna to avoid games with ids = NaN.
rawGamesDf[rawGamesDf.duplicated(keep=False, subset='id')].dropna(subset='id')
# Out:
#                 publisher    genres                          app_name
# 13894  Bethesda Softworks  [Action]  Wolfenstein II: The New Colossus  \
# 14573  Bethesda Softworks  [Action]  Wolfenstein II: The New Colossus
#
#                                   title release_date
# 13894  Wolfenstein II: The New Colossus   2017-10-26  \
# 14573  Wolfenstein II: The New Colossus   2017-10-26
#
#                                                     tags  discount_price
# 13894  [Action, FPS, Gore, Violent, Alternate History...             NaN  \
# 14573  [Action, FPS, Gore, Violent, Alternate History...             NaN
#
#                                                    specs  price  early_access
# 13894  [Single-player, Steam Achievements, Full contr...  59.99         False  \
# 14573  [Single-player, Steam Achievements, Full contr...  59.99         False
#
#            id      developer        sentiment metascore
# 13894  612880  Machine Games  Mostly Positive        86
# 14573  612880  Machine Games  Mostly Positive        86

# %%
index_last_dup_to_remove = rawGamesDf[rawGamesDf.duplicated(keep='last', subset='id')].dropna(subset='id').index
# index_last_dup_to_remove = rawGamesDf[rawGamesDf.duplicated(keep='last', subset='id')].dropna(subset='id')
index_last_dup_to_remove
# Out:
# Index([13894], dtype='int64')

# %%
rawGamesDf.iloc[index_last_dup_to_remove]
# Out:
#                 publisher    genres                          app_name
# 13894  Bethesda Softworks  [Action]  Wolfenstein II: The New Colossus  \
#
#                                   title release_date
# 13894  Wolfenstein II: The New Colossus   2017-10-26  \
#
#                                                     tags  discount_price
# 13894  [Action, FPS, Gore, Violent, Alternate History...             NaN  \
#
#                                                    specs  price  early_access
# 13894  [Single-player, Steam Achievements, Full contr...  59.99         False  \
#
#            id      developer        sentiment metascore
# 13894  612880  Machine Games  Mostly Positive        86

# %%
rawGamesDf.drop(index=index_last_dup_to_remove, inplace=True)

# %%
# Can't use this one yet because of the list in some columns.
# rawGamesDf.drop_duplicates(inplace=True)

# %% [markdown]
# ---

# %% [markdown]
# ## Endpoints, general
#
# Since the data is static and won't change, the most optimal solution could be to prepare a data with every year already processed so the API endpoint can consume it with the least processing in real time.
#
# And since every endpoint to be consumed by the API it needs to know the year, let's process that first.

# %% [markdown]
# ### Year
#
# We only need year for this study so we will create a new column called year with that information. Extracting year with a pattern of four numbers toghether.

# %%
gamesWithYearDf = rawGamesDf

# %%
gamesWithYearDf['release_date'].unique()
# Out:
# array(['2018-01-04', '2017-07-24', '2017-12-07', ..., '2016-11-19',
#        'January 2018', '2018-10-01'], dtype=object)

# %%
# Pattern of regex to extract, 1XXX or 2XXX (valid years).
pattern = '([1-2][0-9][0-9][0-9])'
gamesWithYearDf['year'] = gamesWithYearDf['release_date'].str.extract(pattern, expand = True)

# %%
gamesWithYearDf['year'].head()
# Out:
# 0    2018
# 1    2018
# 2    2017
# 3    2017
# 4     NaN
# Name: year, dtype: object

# %%
gamesWithYearDf['year'].describe()
# Out:
# count     29966
# unique       44
# top        2017
# freq       9594
# Name: year, dtype: object

# %%
gamesWithYearDf['year'].isna().sum()
# Out:
# 2168

# %% [markdown]
# Drop "release_date" and drop NaNs from year since they will not give us relevant information on the APIs queries.

# %%
gamesWithYearDf = gamesWithYearDf.drop(columns='release_date')

# %%
gamesWithYearDf.shape
# Out:
# (32134, 14)

# %%
gamesWithYearDf = gamesWithYearDf.dropna(subset=['year'])

# %%
gamesWithYearDf.shape
# Out:
# (29966, 14)

# %% [markdown]
# Lastly we convert years into int and we can check the years so they are valid years and drop the invalids.

# %%
gamesWithYearDf['year'] = pd.to_numeric(gamesWithYearDf['year'])
gamesWithYearDf['year'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 29966 entries, 0 to 32133
# Series name: year
# Non-Null Count  Dtype
# --------------  -----
# 29966 non-null  int64
# dtypes: int64(1)
# memory usage: 468.2 KB

# %%
gamesWithYearDf[gamesWithYearDf['year'] > 2023]
# Out:
#       publisher                         genres             app_name
# 13428    一次元创作组  [Casual, Indie, Early Access]  Puzzle Sisters Foer  \
#
#                      title                           tags  discount_price
# 13428  Puzzle Sisters Foer  [Early Access, Casual, Indie]             NaN  \
#
#                                                    specs price  early_access
# 13428  [Single-player, Steam Achievements, Steam Trad...   NaN          True  \
#
#            id developer sentiment metascore  year
# 13428  710190    一次元创作组       NaN       NaN  2756

# %%
gamesWithYearDf[gamesWithYearDf['year'] < 1970]
# Out:
# Empty DataFrame
# Columns: [publisher, genres, app_name, title, tags, discount_price, specs, price, early_access, id, developer, sentiment, metascore, year]
# Index: []

# %%
gamesWithYearDf = gamesWithYearDf[gamesWithYearDf['year'] <= 2023]

# %% [markdown]
# ## Endpoint 1: genero
#
# def genero( Año: str ): Se ingresa un año y devuelve una lista con los 5 géneros más vendidos en el orden correspondiente.
#
# Example:
# | Year | Genres |
# | -- | - |
# | 2018 | {'Indie': 125, 'Action': 75, 'Adventure': 74, 'Casual': 45, 'Simulation': 43} |
# | 2016 | {'Indie': 4106, 'Action': 2544, 'Casual': 2141, 'Adventure': 2042, 'Simulation': 1666} |
#
# For this case the only thing that matters to us is "genres" and "year" columns, so we can drop the other ones.

# %%
generoEndpointDf = gamesWithYearDf[['genres', 'year']]
generoEndpointDf.head()
# Out:
#                                               genres  year
# 0      [Action, Casual, Indie, Simulation, Strategy]  2018
# 1               [Free to Play, Indie, RPG, Strategy]  2018
# 2  [Casual, Free to Play, Indie, Simulation, Sports]  2017
# 3                        [Action, Adventure, Casual]  2017
# 5                    [Action, Adventure, Simulation]  2018

# %% [markdown]
# Now we can drop all the columns that have a NaN in any of the two columns because they will bring no information to the scope of the genero function.

# %%
generoEndpointDf.describe()
# Out:
#                year
# count  29965.000000
# mean    2014.769965
# std        3.504090
# min     1970.000000
# 25%     2014.000000
# 50%     2016.000000
# 75%     2017.000000
# max     2021.000000

# %%
generoEndpointDf.isna().sum()
# Out:
# genres    1234
# year         0
# dtype: int64

# %%
generoEndpointDf = generoEndpointDf.dropna()

# %%
generoEndpointDf.isna().sum()
# Out:
# genres    0
# year      0
# dtype: int64

# %% [markdown]
# ### Genre
#
# Each game can have various genres, we can see this in the "genres" column because it is filled with lists.
#
# For this reason we need to explode it so we can count all the genres separately.

# %%
genresCompleteList = generoEndpointDf.explode(column=['genres'])['genres'].unique()
print(genresCompleteList)
print(genresCompleteList.shape)
# Out:
# ['Action' 'Casual' 'Indie' 'Simulation' 'Strategy' 'Free to Play' 'RPG'
#  'Sports' 'Adventure' 'Racing' 'Massively Multiplayer' 'Early Access'
#  'Animation &amp; Modeling' 'Video Production' 'Web Publishing'
#  'Education' 'Software Training' 'Utilities' 'Design &amp; Illustration'
#  'Audio Production' 'Photo Editing' 'Accounting']
# (22,)

# %%
generoEndpointDf.shape
# Out:
# (28731, 2)

# %%
generoEndpointDf = generoEndpointDf.explode('genres')
generoEndpointDf.head()
# Out:
#        genres  year
# 0      Action  2018
# 0      Casual  2018
# 0       Indie  2018
# 0  Simulation  2018
# 0    Strategy  2018

# %%
generoEndpointDf.shape
# Out:
# (71212, 2)

# %% [markdown]
# Now we can make a Groupby to get all the genres of each year. Then unstack it and have a new Data Frame with the data we desire.

# %%
generoEndpointDf2 = generoEndpointDf.groupby(by=['year', 'genres'])['genres'].count()
generoEndpointDf2.tail()
# Out:
# year  genres
# 2019  RPG          2
#       Strategy     1
# 2021  Adventure    1
#       Indie        1
#       RPG          1
# Name: genres, dtype: int64

# %%
generoEndpointDf3 = generoEndpointDf2.unstack(level=1, fill_value=0)
generoEndpointDf3.head()
# Out:
# genres  Accounting  Action  Adventure  Animation &amp; Modeling
# year
# 1983             0       1          1                         0  \
# 1984             0       1          1                         0
# 1985             0       0          0                         0
# 1986             0       0          1                         0
# 1987             0       0          3                         0
#
# genres  Audio Production  Casual  Design &amp; Illustration  Early Access
# year
# 1983                   0       1                          0             0  \
# 1984                   0       2                          0             0
# 1985                   0       0                          0             0
# 1986                   0       1                          0             0
# 1987                   0       0                          0             0
#
# genres  Education  Free to Play  ...  Photo Editing  RPG  Racing  Simulation
# year                             ...
# 1983            0             0  ...              0    0       0           0  \
# 1984            0             0  ...              0    0       0           0
# 1985            0             0  ...              0    0       0           1
# 1986            0             0  ...              0    1       0           1
# 1987            0             0  ...              0    0       0           2
#
# genres  Software Training  Sports  Strategy  Utilities  Video Production
# year
# 1983                    0       0         0          0                 0  \
# 1984                    0       0         0          0                 0
# 1985                    0       0         0          0                 0
# 1986                    0       0         0          0                 0
# 1987                    0       0         0          0                 0
#
# genres  Web Publishing
# year
# 1983                 0
# 1984                 0
# 1985                 0
# 1986                 0
# 1987                 0
#
# [5 rows x 22 columns]

# %%
# Now we have exactly what we need.
generoEndpointDict = generoEndpointDf3.to_dict(orient='index')
generoEndpointDict
# Out:
# {1983: {'Accounting': 0,
#   'Action': 1,
#   'Adventure': 1,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 1,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Indie': 0,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'RPG': 0,
#   'Racing': 0,
#   'Simulation': 0,
#   'Software Training': 0,
#   'Sports': 0,
#   'Strategy': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1984: {'Accounting': 0,
#   'Action': 1,
#   'Adventure': 1,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 2,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Indie': 1,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'RPG': 0,
#   'Racing': 0,
#   'Simulation': 0,
#   'Software Training': 0,
#   'Sports': 0,
#   'Strategy': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1985: {'Accounting': 0,
#   'Action': 0,
#   'Adventure': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Indie': 0,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'RPG': 0,
#   'Racing': 0,
#   'Simulation': 1,
#   'Software Training': 0,
#   'Sports': 0,
#   'Strategy': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1986: {'Accounting': 0,
#   'Action': 0,
#   'Adventure': 1,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 1,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Indie': 1,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'RPG': 1,
#   'Racing': 0,
#   'Simulation': 1,
#   'Software Training': 0,
#   'Sports': 0,
#   'Strategy': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1987: {'Accounting': 0,
#   'Action': 0,
#   'Adventure': 3,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Indie': 0,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'RPG': 0,
#   'Racing': 0,
#   'Simulation': 2,
#   'Software Training': 0,
#   'Sports': 0,
#   'Strategy': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1988: {'Accounting': 0,
#   'Action': 1,
#   'Adventure': 2,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Indie': 1,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'RPG': 1,
#   'Racing': 0,
#   'Simulation': 2,
#   'Software Training': 0,
#   'Sports': 0,
#   'Strategy': 2,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1989: {'Accounting': 0,
#   'Action': 2,
#   'Adventure': 5,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Indie': 0,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'RPG': 1,
#   'Racing': 0,
#   'Simulation': 3,
#   'Software Training': 0,
#   'Sports': 0,
#   'Strategy': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1990: {'Accounting': 0,
#   'Action': 3,
#   'Adventure': 5,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Indie': 0,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'RPG': 1,
#   'Racing': 0,
#   'Simulation': 4,
#   'Software Training': 0,
#   'Sports': 0,
#   'Strategy': 1,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1991: {'Accounting': 0,
#   'Action': 6,
#   'Adventure': 8,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 1,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Indie': 0,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'RPG': 2,
#   'Racing': 0,
#   'Simulation': 2,
#   'Software Training': 0,
#   'Sports': 0,
#   'Strategy': 3,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1992: {'Accounting': 0,
#   'Action': 5,
#   'Adventure': 10,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 1,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Indie': 1,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'RPG': 4,
#   'Racing': 0,
#   'Simulation': 1,
#   'Software Training': 0,
#   'Sports': 0,
#   'Strategy': 2,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1993: {'Accounting': 0,
#   'Action': 13,
#   'Adventure': 15,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 3,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Indie': 0,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'RPG': 2,
#   'Racing': 0,
#   'Simulation': 4,
#   'Software Training': 0,
#   'Sports': 0,
#   'Strategy': 3,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1994: {'Accounting': 0,
#   'Action': 20,
#   'Adventure': 13,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 3,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Indie': 1,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'RPG': 2,
#   'Racing': 2,
#   'Simulation': 7,
#   'Software Training': 0,
#   'Sports': 0,
#   'Strategy': 4,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1995: {'Accounting': 0,
#   'Action': 15,
#   'Adventure': 11,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 4,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Indie': 2,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'RPG': 3,
#   'Racing': 2,
#   'Simulation': 3,
#   'Software Training': 0,
#   'Sports': 2,
#   'Strategy': 7,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1996: {'Accounting': 0,
#   'Action': 13,
#   'Adventure': 16,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 8,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 1,
#   'Indie': 3,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'RPG': 2,
#   'Racing': 3,
#   'Simulation': 3,
#   'Software Training': 0,
#   'Sports': 1,
#   'Strategy': 6,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1997: {'Accounting': 0,
#   'Action': 16,
#   'Adventure': 16,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 8,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Indie': 6,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'RPG': 4,
#   'Racing': 2,
#   'Simulation': 2,
#   'Software Training': 0,
#   'Sports': 1,
#   'Strategy': 9,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1998: {'Accounting': 0,
#   'Action': 22,
#   'Adventure': 15,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 8,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Indie': 5,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'RPG': 2,
#   'Racing': 4,
#   'Simulation': 7,
#   'Software Training': 0,
#   'Sports': 0,
#   'Strategy': 12,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1999: {'Accounting': 0,
#   'Action': 26,
#   'Adventure': 6,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 5,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 1,
#   'Indie': 4,
#   'Massively Multiplayer': 1,
#   'Photo Editing': 0,
#   'RPG': 9,
#   'Racing': 3,
#   'Simulation': 7,
#   'Software Training': 0,
#   'Sports': 2,
#   'Strategy': 16,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  2000: {'Accounting': 0,
#   'Action': 18,
#   'Adventure': 8,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 6,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Indie': 3,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'RPG': 4,
#   'Racing': 1,
#   'Simulation': 7,
#   'Software Training': 0,
#   'Sports': 0,
#   'Strategy': 8,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  2001: {'Accounting': 0,
#   'Action': 25,
#   'Adventure': 14,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 7,
#   'Design &amp; Illustration': 0,
#   'Early Access': 1,
#   'Education': 0,
#   'Free to Play': 3,
#   'Indie': 9,
#   'Massively Multiplayer': 4,
#   'Photo Editing': 0,
#   'RPG': 7,
#   'Racing': 0,
#   'Simulation': 13,
#   'Software Training': 0,
#   'Sports': 0,
#   'Strategy': 26,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  2002: {'Accounting': 0,
#   'Action': 21,
#   'Adventure': 7,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 4,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Indie': 3,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'RPG': 5,
#   'Racing': 0,
#   'Simulation': 5,
#   'Software Training': 0,
#   'Sports': 1,
#   'Strategy': 16,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  2003: {'Accounting': 0,
#   'Action': 34,
#   'Adventure': 20,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 7,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 2,
#   'Indie': 10,
#   'Massively Multiplayer': 2,
#   'Photo Editing': 0,
#   'RPG': 11,
#   'Racing': 2,
#   'Simulation': 4,
#   'Software Training': 0,
#   'Sports': 0,
#   'Strategy': 26,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  2004: {'Accounting': 0,
#   'Action': 28,
#   'Adventure': 11,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 6,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 1,
#   'Indie': 5,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'RPG': 6,
#   'Racing': 1,
#   'Simulation': 10,
#   'Software Training': 0,
#   'Sports': 0,
#   'Strategy': 24,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  2005: {'Accounting': 0,
#   'Action': 38,
#   'Adventure': 15,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 10,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 3,
#   'Indie': 10,
#   'Massively Multiplayer': 1,
#   'Photo Editing': 0,
#   'RPG': 16,
#   'Racing': 8,
#   'Simulation': 9,
#   'Software Training': 0,
#   'Sports': 3,
#   'Strategy': 25,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 1},
#  2006: {'Accounting': 0,
#   'Action': 43,
#   'Adventure': 21,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 27,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 3,
#   'Indie': 22,
#   'Massively Multiplayer': 4,
#   'Photo Editing': 1,
#   'RPG': 12,
#   'Racing': 11,
#   'Simulation': 22,
#   'Software Training': 0,
#   'Sports': 2,
#   'Strategy': 46,
#   'Utilities': 2,
#   'Video Production': 1,
#   'Web Publishing': 0},
#  2007: {'Accounting': 0,
#   'Action': 58,
#   'Adventure': 27,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 2,
#   'Casual': 35,
#   'Design &amp; Illustration': 1,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 7,
#   'Indie': 30,
#   'Massively Multiplayer': 4,
#   'Photo Editing': 1,
#   'RPG': 21,
#   'Racing': 8,
#   'Simulation': 27,
#   'Software Training': 0,
#   'Sports': 2,
#   'Strategy': 33,
#   'Utilities': 1,
#   'Video Production': 1,
#   'Web Publishing': 1},
#  2008: {'Accounting': 0,
#   'Action': 46,
#   'Adventure': 51,
#   'Animation &amp; Modeling': 1,
#   'Audio Production': 0,
#   'Casual': 58,
#   'Design &amp; Illustration': 1,
#   'Early Access': 0,
#   'Education': 1,
#   'Free to Play': 6,
#   'Indie': 55,
#   'Massively Multiplayer': 5,
#   'Photo Editing': 0,
#   'RPG': 27,
#   'Racing': 14,
#   'Simulation': 24,
#   'Software Training': 1,
#   'Sports': 5,
#   'Strategy': 35,
#   'Utilities': 1,
#   'Video Production': 0,
#   'Web Publishing': 1},
#  2009: {'Accounting': 0,
#   'Action': 86,
#   'Adventure': 54,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 67,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 4,
#   'Indie': 70,
#   'Massively Multiplayer': 2,
#   'Photo Editing': 0,
#   'RPG': 33,
#   'Racing': 10,
#   'Simulation': 83,
#   'Software Training': 0,
#   'Sports': 9,
#   'Strategy': 73,
#   'Utilities': 1,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  2010: {'Accounting': 0,
#   'Action': 150,
#   'Adventure': 85,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 70,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 4,
#   'Free to Play': 7,
#   'Indie': 110,
#   'Massively Multiplayer': 2,
#   'Photo Editing': 0,
#   'RPG': 56,
#   'Racing': 11,
#   'Simulation': 57,
#   'Software Training': 1,
#   'Sports': 4,
#   'Strategy': 106,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  2011: {'Accounting': 0,
#   'Action': 223,
#   'Adventure': 87,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 97,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 12,
#   'Indie': 179,
#   'Massively Multiplayer': 9,
#   'Photo Editing': 0,
#   'RPG': 89,
#   'Racing': 21,
#   'Simulation': 86,
#   'Software Training': 0,
#   'Sports': 11,
#   'Strategy': 173,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  2012: {'Accounting': 0,
#   'Action': 505,
#   'Adventure': 191,
#   'Animation &amp; Modeling': 3,
#   'Audio Production': 0,
#   'Casual': 240,
#   'Design &amp; Illustration': 1,
#   'Early Access': 2,
#   'Education': 0,
#   'Free to Play': 41,
#   'Indie': 347,
#   'Massively Multiplayer': 21,
#   'Photo Editing': 1,
#   'RPG': 136,
#   'Racing': 30,
#   'Simulation': 281,
#   'Software Training': 0,
#   'Sports': 6,
#   'Strategy': 299,
#   'Utilities': 2,
#   'Video Production': 2,
#   'Web Publishing': 1},
#  2013: {'Accounting': 0,
#   'Action': 604,
#   'Adventure': 331,
#   'Animation &amp; Modeling': 10,
#   'Audio Production': 6,
#   'Casual': 286,
#   'Design &amp; Illustration': 28,
#   'Early Access': 10,
#   'Education': 9,
#   'Free to Play': 78,
#   'Indie': 469,
#   'Massively Multiplayer': 35,
#   'Photo Editing': 0,
#   'RPG': 214,
#   'Racing': 47,
#   'Simulation': 375,
#   'Software Training': 7,
#   'Sports': 46,
#   'Strategy': 411,
#   'Utilities': 17,
#   'Video Production': 4,
#   'Web Publishing': 30},
#  2014: {'Accounting': 0,
#   'Action': 1023,
#   'Adventure': 684,
#   'Animation &amp; Modeling': 26,
#   'Audio Production': 17,
#   'Casual': 715,
#   'Design &amp; Illustration': 60,
#   'Early Access': 78,
#   'Education': 13,
#   'Free to Play': 169,
#   'Indie': 1359,
#   'Massively Multiplayer': 98,
#   'Photo Editing': 4,
#   'RPG': 566,
#   'Racing': 79,
#   'Simulation': 707,
#   'Software Training': 12,
#   'Sports': 101,
#   'Strategy': 570,
#   'Utilities': 33,
#   'Video Production': 9,
#   'Web Publishing': 44},
#  2015: {'Accounting': 2,
#   'Action': 2033,
#   'Adventure': 1502,
#   'Animation &amp; Modeling': 38,
#   'Audio Production': 17,
#   'Casual': 1217,
#   'Design &amp; Illustration': 88,
#   'Early Access': 224,
#   'Education': 25,
#   'Free to Play': 333,
#   'Indie': 2828,
#   'Massively Multiplayer': 182,
#   'Photo Editing': 29,
#   'RPG': 972,
#   'Racing': 162,
#   'Simulation': 1173,
#   'Software Training': 35,
#   'Sports': 179,
#   'Strategy': 1087,
#   'Utilities': 87,
#   'Video Production': 24,
#   'Web Publishing': 35},
#  2016: {'Accounting': 1,
#   'Action': 2544,
#   'Adventure': 2042,
#   'Animation &amp; Modeling': 52,
#   'Audio Production': 24,
#   'Casual': 2141,
#   'Design &amp; Illustration': 123,
#   'Early Access': 363,
#   'Education': 29,
#   'Free to Play': 555,
#   'Indie': 4106,
#   'Massively Multiplayer': 310,
#   'Photo Editing': 15,
#   'RPG': 1272,
#   'Racing': 283,
#   'Simulation': 1666,
#   'Software Training': 21,
#   'Sports': 355,
#   'Strategy': 1607,
#   'Utilities': 92,
#   'Video Production': 31,
#   'Web Publishing': 61},
#  2017: {'Accounting': 4,
#   'Action': 3556,
#   'Adventure': 2839,
#   'Animation &amp; Modeling': 53,
#   'Audio Production': 27,
#   'Casual': 3172,
#   'Design &amp; Illustration': 157,
#   'Early Access': 733,
#   'Education': 43,
#   'Free to Play': 786,
#   'Indie': 5994,
#   'Massively Multiplayer': 422,
#   'Photo Editing': 26,
#   'RPG': 1927,
#   'Racing': 371,
#   'Simulation': 2039,
#   'Software Training': 28,
#   'Sports': 512,
#   'Strategy': 2271,
#   'Utilities': 101,
#   'Video Production': 44,
#   'Web Publishing': 94},
#  2018: {'Accounting': 0,
#   'Action': 75,
#   'Adventure': 74,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 45,
#   'Design &amp; Illustration': 1,
#   'Early Access': 33,
#   'Education': 1,
#   'Free to Play': 13,
#   'Indie': 125,
#   'Massively Multiplayer': 3,
#   'Photo Editing': 0,
#   'RPG': 40,
#   'Racing': 5,
#   'Simulation': 43,
#   'Software Training': 0,
#   'Sports': 12,
#   'Strategy': 28,
#   'Utilities': 1,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  2019: {'Accounting': 0,
#   'Action': 2,
#   'Adventure': 3,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 1,
#   'Education': 0,
#   'Free to Play': 1,
#   'Indie': 3,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'RPG': 2,
#   'Racing': 0,
#   'Simulation': 0,
#   'Software Training': 0,
#   'Sports': 0,
#   'Strategy': 1,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  2021: {'Accounting': 0,
#   'Action': 0,
#   'Adventure': 1,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Indie': 1,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'RPG': 1,
#   'Racing': 0,
#   'Simulation': 0,
#   'Software Training': 0,
#   'Sports': 0,
#   'Strategy': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0}}

# %% [markdown]
# Sort by values.

# %%
generoEndpointDict_sorted = {}
for y in generoEndpointDict.keys():
    genres = generoEndpointDict[y]
    genres_sorted = {k: v for k, v in sorted(genres.items(), key=lambda item: item[1], reverse=True)}
    # print(genres_sorted)
    generoEndpointDict_sorted[y] = genres_sorted

generoEndpointDict_sorted
# Out:
# {1983: {'Action': 1,
#   'Adventure': 1,
#   'Casual': 1,
#   'Accounting': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Indie': 0,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'RPG': 0,
#   'Racing': 0,
#   'Simulation': 0,
#   'Software Training': 0,
#   'Sports': 0,
#   'Strategy': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1984: {'Casual': 2,
#   'Action': 1,
#   'Adventure': 1,
#   'Indie': 1,
#   'Accounting': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'RPG': 0,
#   'Racing': 0,
#   'Simulation': 0,
#   'Software Training': 0,
#   'Sports': 0,
#   'Strategy': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1985: {'Simulation': 1,
#   'Accounting': 0,
#   'Action': 0,
#   'Adventure': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Indie': 0,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'RPG': 0,
#   'Racing': 0,
#   'Software Training': 0,
#   'Sports': 0,
#   'Strategy': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1986: {'Adventure': 1,
#   'Casual': 1,
#   'Indie': 1,
#   'RPG': 1,
#   'Simulation': 1,
#   'Accounting': 0,
#   'Action': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'Racing': 0,
#   'Software Training': 0,
#   'Sports': 0,
#   'Strategy': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1987: {'Adventure': 3,
#   'Simulation': 2,
#   'Accounting': 0,
#   'Action': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Indie': 0,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'RPG': 0,
#   'Racing': 0,
#   'Software Training': 0,
#   'Sports': 0,
#   'Strategy': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1988: {'Adventure': 2,
#   'Simulation': 2,
#   'Strategy': 2,
#   'Action': 1,
#   'Indie': 1,
#   'RPG': 1,
#   'Accounting': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'Racing': 0,
#   'Software Training': 0,
#   'Sports': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1989: {'Adventure': 5,
#   'Simulation': 3,
#   'Action': 2,
#   'RPG': 1,
#   'Accounting': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Indie': 0,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'Racing': 0,
#   'Software Training': 0,
#   'Sports': 0,
#   'Strategy': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1990: {'Adventure': 5,
#   'Simulation': 4,
#   'Action': 3,
#   'RPG': 1,
#   'Strategy': 1,
#   'Accounting': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Indie': 0,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'Racing': 0,
#   'Software Training': 0,
#   'Sports': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1991: {'Adventure': 8,
#   'Action': 6,
#   'Strategy': 3,
#   'RPG': 2,
#   'Simulation': 2,
#   'Casual': 1,
#   'Accounting': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Indie': 0,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'Racing': 0,
#   'Software Training': 0,
#   'Sports': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1992: {'Adventure': 10,
#   'Action': 5,
#   'RPG': 4,
#   'Strategy': 2,
#   'Casual': 1,
#   'Indie': 1,
#   'Simulation': 1,
#   'Accounting': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'Racing': 0,
#   'Software Training': 0,
#   'Sports': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1993: {'Adventure': 15,
#   'Action': 13,
#   'Simulation': 4,
#   'Casual': 3,
#   'Strategy': 3,
#   'RPG': 2,
#   'Accounting': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Indie': 0,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'Racing': 0,
#   'Software Training': 0,
#   'Sports': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1994: {'Action': 20,
#   'Adventure': 13,
#   'Simulation': 7,
#   'Strategy': 4,
#   'Casual': 3,
#   'RPG': 2,
#   'Racing': 2,
#   'Indie': 1,
#   'Accounting': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'Software Training': 0,
#   'Sports': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1995: {'Action': 15,
#   'Adventure': 11,
#   'Strategy': 7,
#   'Casual': 4,
#   'RPG': 3,
#   'Simulation': 3,
#   'Indie': 2,
#   'Racing': 2,
#   'Sports': 2,
#   'Accounting': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'Software Training': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1996: {'Adventure': 16,
#   'Action': 13,
#   'Casual': 8,
#   'Strategy': 6,
#   'Indie': 3,
#   'Racing': 3,
#   'Simulation': 3,
#   'RPG': 2,
#   'Free to Play': 1,
#   'Sports': 1,
#   'Accounting': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'Software Training': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1997: {'Action': 16,
#   'Adventure': 16,
#   'Strategy': 9,
#   'Casual': 8,
#   'Indie': 6,
#   'RPG': 4,
#   'Racing': 2,
#   'Simulation': 2,
#   'Sports': 1,
#   'Accounting': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'Software Training': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1998: {'Action': 22,
#   'Adventure': 15,
#   'Strategy': 12,
#   'Casual': 8,
#   'Simulation': 7,
#   'Indie': 5,
#   'Racing': 4,
#   'RPG': 2,
#   'Accounting': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'Software Training': 0,
#   'Sports': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1999: {'Action': 26,
#   'Strategy': 16,
#   'RPG': 9,
#   'Simulation': 7,
#   'Adventure': 6,
#   'Casual': 5,
#   'Indie': 4,
#   'Racing': 3,
#   'Sports': 2,
#   'Free to Play': 1,
#   'Massively Multiplayer': 1,
#   'Accounting': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Photo Editing': 0,
#   'Software Training': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  2000: {'Action': 18,
#   'Adventure': 8,
#   'Strategy': 8,
#   'Simulation': 7,
#   'Casual': 6,
#   'RPG': 4,
#   'Indie': 3,
#   'Racing': 1,
#   'Accounting': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'Software Training': 0,
#   'Sports': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  2001: {'Strategy': 26,
#   'Action': 25,
#   'Adventure': 14,
#   'Simulation': 13,
#   'Indie': 9,
#   'Casual': 7,
#   'RPG': 7,
#   'Massively Multiplayer': 4,
#   'Free to Play': 3,
#   'Early Access': 1,
#   'Accounting': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Design &amp; Illustration': 0,
#   'Education': 0,
#   'Photo Editing': 0,
#   'Racing': 0,
#   'Software Training': 0,
#   'Sports': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  2002: {'Action': 21,
#   'Strategy': 16,
#   'Adventure': 7,
#   'RPG': 5,
#   'Simulation': 5,
#   'Casual': 4,
#   'Indie': 3,
#   'Sports': 1,
#   'Accounting': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'Racing': 0,
#   'Software Training': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  2003: {'Action': 34,
#   'Strategy': 26,
#   'Adventure': 20,
#   'RPG': 11,
#   'Indie': 10,
#   'Casual': 7,
#   'Simulation': 4,
#   'Free to Play': 2,
#   'Massively Multiplayer': 2,
#   'Racing': 2,
#   'Accounting': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Photo Editing': 0,
#   'Software Training': 0,
#   'Sports': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  2004: {'Action': 28,
#   'Strategy': 24,
#   'Adventure': 11,
#   'Simulation': 10,
#   'Casual': 6,
#   'RPG': 6,
#   'Indie': 5,
#   'Free to Play': 1,
#   'Racing': 1,
#   'Accounting': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'Software Training': 0,
#   'Sports': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  2005: {'Action': 38,
#   'Strategy': 25,
#   'RPG': 16,
#   'Adventure': 15,
#   'Casual': 10,
#   'Indie': 10,
#   'Simulation': 9,
#   'Racing': 8,
#   'Free to Play': 3,
#   'Sports': 3,
#   'Massively Multiplayer': 1,
#   'Web Publishing': 1,
#   'Accounting': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Photo Editing': 0,
#   'Software Training': 0,
#   'Utilities': 0,
#   'Video Production': 0},
#  2006: {'Strategy': 46,
#   'Action': 43,
#   'Casual': 27,
#   'Indie': 22,
#   'Simulation': 22,
#   'Adventure': 21,
#   'RPG': 12,
#   'Racing': 11,
#   'Massively Multiplayer': 4,
#   'Free to Play': 3,
#   'Sports': 2,
#   'Utilities': 2,
#   'Photo Editing': 1,
#   'Video Production': 1,
#   'Accounting': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Software Training': 0,
#   'Web Publishing': 0},
#  2007: {'Action': 58,
#   'Casual': 35,
#   'Strategy': 33,
#   'Indie': 30,
#   'Adventure': 27,
#   'Simulation': 27,
#   'RPG': 21,
#   'Racing': 8,
#   'Free to Play': 7,
#   'Massively Multiplayer': 4,
#   'Audio Production': 2,
#   'Sports': 2,
#   'Design &amp; Illustration': 1,
#   'Photo Editing': 1,
#   'Utilities': 1,
#   'Video Production': 1,
#   'Web Publishing': 1,
#   'Accounting': 0,
#   'Animation &amp; Modeling': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Software Training': 0},
#  2008: {'Casual': 58,
#   'Indie': 55,
#   'Adventure': 51,
#   'Action': 46,
#   'Strategy': 35,
#   'RPG': 27,
#   'Simulation': 24,
#   'Racing': 14,
#   'Free to Play': 6,
#   'Massively Multiplayer': 5,
#   'Sports': 5,
#   'Animation &amp; Modeling': 1,
#   'Design &amp; Illustration': 1,
#   'Education': 1,
#   'Software Training': 1,
#   'Utilities': 1,
#   'Web Publishing': 1,
#   'Accounting': 0,
#   'Audio Production': 0,
#   'Early Access': 0,
#   'Photo Editing': 0,
#   'Video Production': 0},
#  2009: {'Action': 86,
#   'Simulation': 83,
#   'Strategy': 73,
#   'Indie': 70,
#   'Casual': 67,
#   'Adventure': 54,
#   'RPG': 33,
#   'Racing': 10,
#   'Sports': 9,
#   'Free to Play': 4,
#   'Massively Multiplayer': 2,
#   'Utilities': 1,
#   'Accounting': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Photo Editing': 0,
#   'Software Training': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  2010: {'Action': 150,
#   'Indie': 110,
#   'Strategy': 106,
#   'Adventure': 85,
#   'Casual': 70,
#   'Simulation': 57,
#   'RPG': 56,
#   'Racing': 11,
#   'Free to Play': 7,
#   'Education': 4,
#   'Sports': 4,
#   'Massively Multiplayer': 2,
#   'Software Training': 1,
#   'Accounting': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Photo Editing': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  2011: {'Action': 223,
#   'Indie': 179,
#   'Strategy': 173,
#   'Casual': 97,
#   'RPG': 89,
#   'Adventure': 87,
#   'Simulation': 86,
#   'Racing': 21,
#   'Free to Play': 12,
#   'Sports': 11,
#   'Massively Multiplayer': 9,
#   'Accounting': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Photo Editing': 0,
#   'Software Training': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  2012: {'Action': 505,
#   'Indie': 347,
#   'Strategy': 299,
#   'Simulation': 281,
#   'Casual': 240,
#   'Adventure': 191,
#   'RPG': 136,
#   'Free to Play': 41,
#   'Racing': 30,
#   'Massively Multiplayer': 21,
#   'Sports': 6,
#   'Animation &amp; Modeling': 3,
#   'Early Access': 2,
#   'Utilities': 2,
#   'Video Production': 2,
#   'Design &amp; Illustration': 1,
#   'Photo Editing': 1,
#   'Web Publishing': 1,
#   'Accounting': 0,
#   'Audio Production': 0,
#   'Education': 0,
#   'Software Training': 0},
#  2013: {'Action': 604,
#   'Indie': 469,
#   'Strategy': 411,
#   'Simulation': 375,
#   'Adventure': 331,
#   'Casual': 286,
#   'RPG': 214,
#   'Free to Play': 78,
#   'Racing': 47,
#   'Sports': 46,
#   'Massively Multiplayer': 35,
#   'Web Publishing': 30,
#   'Design &amp; Illustration': 28,
#   'Utilities': 17,
#   'Animation &amp; Modeling': 10,
#   'Early Access': 10,
#   'Education': 9,
#   'Software Training': 7,
#   'Audio Production': 6,
#   'Video Production': 4,
#   'Accounting': 0,
#   'Photo Editing': 0},
#  2014: {'Indie': 1359,
#   'Action': 1023,
#   'Casual': 715,
#   'Simulation': 707,
#   'Adventure': 684,
#   'Strategy': 570,
#   'RPG': 566,
#   'Free to Play': 169,
#   'Sports': 101,
#   'Massively Multiplayer': 98,
#   'Racing': 79,
#   'Early Access': 78,
#   'Design &amp; Illustration': 60,
#   'Web Publishing': 44,
#   'Utilities': 33,
#   'Animation &amp; Modeling': 26,
#   'Audio Production': 17,
#   'Education': 13,
#   'Software Training': 12,
#   'Video Production': 9,
#   'Photo Editing': 4,
#   'Accounting': 0},
#  2015: {'Indie': 2828,
#   'Action': 2033,
#   'Adventure': 1502,
#   'Casual': 1217,
#   'Simulation': 1173,
#   'Strategy': 1087,
#   'RPG': 972,
#   'Free to Play': 333,
#   'Early Access': 224,
#   'Massively Multiplayer': 182,
#   'Sports': 179,
#   'Racing': 162,
#   'Design &amp; Illustration': 88,
#   'Utilities': 87,
#   'Animation &amp; Modeling': 38,
#   'Software Training': 35,
#   'Web Publishing': 35,
#   'Photo Editing': 29,
#   'Education': 25,
#   'Video Production': 24,
#   'Audio Production': 17,
#   'Accounting': 2},
#  2016: {'Indie': 4106,
#   'Action': 2544,
#   'Casual': 2141,
#   'Adventure': 2042,
#   'Simulation': 1666,
#   'Strategy': 1607,
#   'RPG': 1272,
#   'Free to Play': 555,
#   'Early Access': 363,
#   'Sports': 355,
#   'Massively Multiplayer': 310,
#   'Racing': 283,
#   'Design &amp; Illustration': 123,
#   'Utilities': 92,
#   'Web Publishing': 61,
#   'Animation &amp; Modeling': 52,
#   'Video Production': 31,
#   'Education': 29,
#   'Audio Production': 24,
#   'Software Training': 21,
#   'Photo Editing': 15,
#   'Accounting': 1},
#  2017: {'Indie': 5994,
#   'Action': 3556,
#   'Casual': 3172,
#   'Adventure': 2839,
#   'Strategy': 2271,
#   'Simulation': 2039,
#   'RPG': 1927,
#   'Free to Play': 786,
#   'Early Access': 733,
#   'Sports': 512,
#   'Massively Multiplayer': 422,
#   'Racing': 371,
#   'Design &amp; Illustration': 157,
#   'Utilities': 101,
#   'Web Publishing': 94,
#   'Animation &amp; Modeling': 53,
#   'Video Production': 44,
#   'Education': 43,
#   'Software Training': 28,
#   'Audio Production': 27,
#   'Photo Editing': 26,
#   'Accounting': 4},
#  2018: {'Indie': 125,
#   'Action': 75,
#   'Adventure': 74,
#   'Casual': 45,
#   'Simulation': 43,
#   'RPG': 40,
#   'Early Access': 33,
#   'Strategy': 28,
#   'Free to Play': 13,
#   'Sports': 12,
#   'Racing': 5,
#   'Massively Multiplayer': 3,
#   'Design &amp; Illustration': 1,
#   'Education': 1,
#   'Utilities': 1,
#   'Accounting': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Photo Editing': 0,
#   'Software Training': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  2019: {'Adventure': 3,
#   'Indie': 3,
#   'Action': 2,
#   'RPG': 2,
#   'Early Access': 1,
#   'Free to Play': 1,
#   'Strategy': 1,
#   'Accounting': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 0,
#   'Design &amp; Illustration': 0,
#   'Education': 0,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'Racing': 0,
#   'Simulation': 0,
#   'Software Training': 0,
#   'Sports': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  2021: {'Adventure': 1,
#   'Indie': 1,
#   'RPG': 1,
#   'Accounting': 0,
#   'Action': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'Racing': 0,
#   'Simulation': 0,
#   'Software Training': 0,
#   'Sports': 0,
#   'Strategy': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0}}

# %%
with open("datasets/steam_games_endpoint_1_genero.json", "w") as outfile:
    json.dump(generoEndpointDict_sorted, outfile)

# %% [markdown]
# **TEST**

# %%
def genero(Year: str): 
    """
    Se ingresa un año y devuelve un diccionario con los 5 géneros más vendidos en el orden correspondiente.
    """

    # Read data
    with open("datasets/steam_games_endpoint_1_genero.json") as json_file:
        genres_dict = json.load(json_file)
    # Since data is already sorted, get the first 5 as top 5.
    top5 = dict(list(genres_dict[Year].items())[0:5])
    return top5

genero('2016')
# Out:
# {'Indie': 4106,
#  'Action': 2544,
#  'Casual': 2141,
#  'Adventure': 2042,
#  'Simulation': 1666}

# %% [markdown]
# ---

# %% [markdown]
# ## Endpoint 2: juegos
#
# def juegos( Año: str ): Se ingresa un año y devuelve una lista con los juegos lanzados en el año.
#
# Example:
# | Year | Games |
# | -- | - |
# | 2018 | ['juego1', 'juego2', ... ] |
# | 2016 | ['juegoX', 'juegoY', ... ] |
#
# For this case the only thing that matters to us is "app_name", "title" and "year" columns, so we can drop the other ones.

# %%
juegosEndpointDf = gamesWithYearDf[['app_name', 'title', 'year']]
juegosEndpointDf.head()
# Out:
#                   app_name                    title  year
# 0      Lost Summoner Kitty      Lost Summoner Kitty  2018
# 1                Ironbound                Ironbound  2018
# 2  Real Pool 3D - Poolians  Real Pool 3D - Poolians  2017
# 3                  弹炸人2222                  弹炸人2222  2017
# 5    Battle Royale Trainer    Battle Royale Trainer  2018

# %% [markdown]
# First let's study and unify app_name and title into one. It only has one NaN each and it is in the same row, so we drop it.

# %%
print("Unique:",juegosEndpointDf['app_name'].unique())
print("NaNs:", juegosEndpointDf['app_name'].isna().sum())
# Out:
# Unique: ['Lost Summoner Kitty' 'Ironbound' 'Real Pool 3D - Poolians' ...
#  'LOGistICAL: South Africa' 'Russian Roads' 'EXIT 2 - Directions']
# NaNs: 1

# %%
print("Unique:",juegosEndpointDf['title'].unique())
print("NaNs:", juegosEndpointDf['title'].isna().sum())
# Out:
# Unique: ['Lost Summoner Kitty' 'Ironbound' 'Real Pool 3D - Poolians' ...
#  'LOGistICAL: South Africa' 'Russian Roads' 'EXIT 2 - Directions']
# NaNs: 1

# %%
juegosEndpointDf[juegosEndpointDf['title'].isna()]
# Out:
#      app_name title  year
# 2580      NaN   NaN  2014

# %%
juegosEndpointDf.shape
# Out:
# (29965, 3)

# %%
juegosEndpointDf = juegosEndpointDf.dropna(subset=['app_name', 'title'])

# %%
juegosEndpointDf.shape
# Out:
# (29964, 3)

# %% [markdown]
# Comparing the difference of game names it looks better the characters in "app_name", so we drop "title".

# %%
juegosEndpointDf[juegosEndpointDf['app_name'] != juegosEndpointDf['title']].tail()
# Out:
#                                      app_name
# 31871              Sam & Max 105: Reality 2.0  \
# 31872    Sam & Max 104: Abe Lincoln Must Die!
# 31873  Sam & Max 106: Bright Side of the Moon
# 31898    Making History: The Calm & the Storm
# 32052           Dark Messiah of Might & Magic
#
#                                             title  year
# 31871              Sam &amp; Max 105: Reality 2.0  2007
# 31872    Sam &amp; Max 104: Abe Lincoln Must Die!  2007
# 31873  Sam &amp; Max 106: Bright Side of the Moon  2007
# 31898    Making History: The Calm &amp; the Storm  2007
# 32052           Dark Messiah of Might &amp; Magic  2006

# %%
juegosEndpointDf = juegosEndpointDf.drop(columns='title')

# %% [markdown]
# ### Games
#
# Each game has the name on column "app_name". Let's prepare the json.

# %%
juegosEndpointDf.shape
# Out:
# (29964, 2)

# %% [markdown]
# Now we can make a Groupby to get all the genres of each year. THen unstack it and have a new Data Frame with the data we desire.

# %%
# juegosEndpointDf2 = juegosEndpointDf.groupby(by=['year']).apply(lambda df: dict(df['app_name']))
juegosEndpointDf2 = juegosEndpointDf.groupby(by=['year']).apply(lambda df: list(df['app_name']))

juegosEndpointDf2.tail(20)
# Out:
# year
# 2001    [Return to Castle Wolfenstein, Max Payne, X-CO...
# 2002    [Arx Fatalis, The Sum of All Fears, Freedom Fo...
# 2003    [Ghost Master®, Railroad Tycoon 3, BloodRayne,...
# 2004    [Rome: Total War™ - Collection, Manhunt, Far C...
# 2005    [Advent Rising, FlatOut, Act of War: Direct Ac...
# 2006    [Disciples II: Gallean's Return, Disciples II:...
# 2007    [Lost Planet™: Extreme Condition, RIP - Trilog...
# 2008    [Command & Conquer: Red Alert 3, Conflict: Den...
# 2009    [PRR Wagon Pack 01, Class 421 London South Eas...
# 2010    [Avencast: Rise of the Mage, Pirates, Vikings,...
# 2011    [Mafia II, Lara Croft GoL: Raziel and Kain Cha...
# 2012    [Hard Reset Extended Edition, Blackwell Unboun...
# 2013    [RIFT, Trine 2: Complete Story, Angelica Weave...
# 2014    [Imagine Earth, BeatBlasters III, Blood of the...
# 2015    [Assault Android Cactus, America's Army: Provi...
# 2016    [Fallen Mage, Of Guards And Thieves, The Inter...
# 2017    [Real Pool 3D - Poolians, 弹炸人2222, RC Plane 3 ...
# 2018    [Lost Summoner Kitty, Ironbound, Battle Royale...
# 2019    [Raji: An Ancient Epic, K'NOSSOS, The Legendar...
# 2021                        [Finding Paradise Soundtrack]
# dtype: object

# %%
juegosEndpointDict = dict(juegosEndpointDf2)

# %%
with open("datasets/steam_games_endpoint_2_juegos.json", "w") as outfile:
    json.dump(juegosEndpointDict, outfile)

# %% [markdown]
# **TEST**

# %%
def juegos( Year: str ):
    """
    Se ingresa un año y devuelve un diccionario con los juegos lanzados en el año.
    """
    # Read data
    with open("datasets/steam_games_endpoint_2_juegos.json") as json_file:
        juegos_dict = json.load(json_file)
    return juegos_dict[Year]

juegos('2020')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[70], line 10
#       7         juegos_dict = json.load(json_file)
#       8     return juegos_dict[Year]
# ---> 10 juegos('2020')
#
# Cell In[70], line 8, in juegos(Year)
#       6 with open("datasets/steam_games_endpoint_2_juegos.json") as json_file:
#       7     juegos_dict = json.load(json_file)
# ----> 8 return juegos_dict[Year]
#
# KeyError: '2020'

# %% [markdown]
# ---

# %% [markdown]
# ## Endpoint 3: specs
#
# def specs( Año: str ): Se ingresa un año y devuelve una lista con los 5 specs que más se repiten en el mismo en el orden correspondiente.
#
# Example:
# | Year | Specs |
# | -- | - |
# | 2018 | {'Indie': 125, 'Action': 75, 'Adventure': 74, 'Casual': 45, 'Simulation': 43} |
# | 2016 | {'Indie': 4106, 'Action': 2544, 'Casual': 2141, 'Adventure': 2042, 'Simulation': 1666} |
#
# For this case the only thing that matters to us is "specs" and "year" columns, so we can drop the other ones.

# %%
specsEndpointDf = gamesWithYearDf[['specs', 'year']]
specsEndpointDf.head()
# Out:
#                                                specs  year
# 0                                    [Single-player]  2018
# 1  [Single-player, Multi-player, Online Multi-Pla...  2018
# 2  [Single-player, Multi-player, Online Multi-Pla...  2017
# 3                                    [Single-player]  2017
# 5                [Single-player, Steam Achievements]  2018

# %% [markdown]
# Now we can drop all the columns that have a NaN in any of the two columns because they will bring no information to the scope of the genero function.

# %%
specsEndpointDf.describe()
# Out:
#                year
# count  29965.000000
# mean    2014.769965
# std        3.504090
# min     1970.000000
# 25%     2014.000000
# 50%     2016.000000
# 75%     2017.000000
# max     2021.000000

# %%
specsEndpointDf.isna().sum()
# Out:
# specs    669
# year       0
# dtype: int64

# %%
specsEndpointDf = specsEndpointDf.dropna()

# %%
specsEndpointDf.isna().sum()
# Out:
# specs    0
# year     0
# dtype: int64

# %% [markdown]
# ### Specs
#
# Similarly to genres, each game can have various specs, we can see this in the "specs" column because it is filled with lists.
#
# For this reason we need to explode it so we can count all the specs separately.

# %%
specsCompleteList = specsEndpointDf.explode(column=['specs'])['specs'].unique()
print(specsCompleteList)
print(specsCompleteList.shape)
# Out:
# ['Single-player' 'Multi-player' 'Online Multi-Player'
#  'Cross-Platform Multiplayer' 'Steam Achievements' 'Steam Trading Cards'
#  'In-App Purchases' 'Stats' 'Downloadable Content'
#  'Full controller support' 'Steam Cloud' 'Steam Leaderboards'
#  'Partial Controller Support' 'Local Co-op' 'Shared/Split Screen'
#  'Valve Anti-Cheat enabled' 'Local Multi-Player'
#  'Steam Turn Notifications' 'MMO' 'Co-op' 'Captions available'
#  'Steam Workshop' 'Includes level editor' 'Mods' 'Mods (require HL2)'
#  'Online Co-op' 'Game demo' 'Includes Source SDK' 'Commentary available'
#  'SteamVR Collectibles' 'Mods (require HL1)']
# (31,)

# %%
specsEndpointDf.shape
# Out:
# (28731, 2)

# %%
specsEndpointDf = specsEndpointDf.explode('specs')
specsEndpointDf.head()
# Out:
#                         specs  year
# 0               Single-player  2018
# 1               Single-player  2018
# 1                Multi-player  2018
# 1         Online Multi-Player  2018
# 1  Cross-Platform Multiplayer  2018

# %%
specsEndpointDf.shape
# Out:
# (128228, 2)

# %% [markdown]
# Now we can make a Groupby to get all the specs of each year. Then unstack it and have a new Data Frame with the data we desire.

# %%
specsEndpointDf2 = specsEndpointDf.groupby(by=['year', 'specs'])['specs'].count()
specsEndpointDf2.tail()
# Out:
# year  specs
# 2019  Single-player           4
#       Steam Achievements      2
#       Steam Cloud             1
# 2021  Downloadable Content    1
#       Single-player           1
# Name: specs, dtype: int64

# %%
specsEndpointDf3 = specsEndpointDf2.unstack(level=1, fill_value=0)
specsEndpointDf3.head()
# Out:
# specs  Captions available  Co-op  Commentary available
# year
# 1970                    2      0                     0  \
# 1975                    1      0                     0
# 1980                    1      0                     0
# 1981                    2      0                     0
# 1982                    3      0                     0
#
# specs  Cross-Platform Multiplayer  Downloadable Content
# year
# 1970                            0                     0  \
# 1975                            0                     0
# 1980                            0                     0
# 1981                            0                     0
# 1982                            0                     0
#
# specs  Full controller support  Game demo  In-App Purchases
# year
# 1970                         0          0                 0  \
# 1975                         0          0                 0
# 1980                         0          0                 0
# 1981                         0          0                 0
# 1982                         0          0                 0
#
# specs  Includes Source SDK  Includes level editor  ...  Single-player  Stats
# year                                               ...
# 1970                     0                      0  ...              0      0  \
# 1975                     0                      0  ...              0      0
# 1980                     0                      0  ...              0      0
# 1981                     0                      0  ...              0      0
# 1982                     0                      0  ...              0      0
#
# specs  Steam Achievements  Steam Cloud  Steam Leaderboards
# year
# 1970                    0            0                   0  \
# 1975                    0            0                   0
# 1980                    0            0                   0
# 1981                    0            0                   0
# 1982                    0            0                   0
#
# specs  Steam Trading Cards  Steam Turn Notifications  Steam Workshop
# year
# 1970                     0                         0               0  \
# 1975                     0                         0               0
# 1980                     0                         0               0
# 1981                     0                         0               0
# 1982                     0                         0               0
#
# specs  SteamVR Collectibles  Valve Anti-Cheat enabled
# year
# 1970                      0                         0
# 1975                      0                         0
# 1980                      0                         0
# 1981                      0                         0
# 1982                      0                         0
#
# [5 rows x 31 columns]

# %%
# Now we have exactly what we need.
specsEndpointDict = specsEndpointDf3.to_dict(orient='index')
specsEndpointDict
# Out:
# {1970: {'Captions available': 2,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 0,
#   'Shared/Split Screen': 0,
#   'Single-player': 0,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Cloud': 0,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1975: {'Captions available': 1,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 0,
#   'Shared/Split Screen': 0,
#   'Single-player': 0,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Cloud': 0,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1980: {'Captions available': 1,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 0,
#   'Shared/Split Screen': 0,
#   'Single-player': 0,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Cloud': 0,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1981: {'Captions available': 2,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 0,
#   'Shared/Split Screen': 0,
#   'Single-player': 0,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Cloud': 0,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1982: {'Captions available': 3,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 0,
#   'Shared/Split Screen': 0,
#   'Single-player': 0,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Cloud': 0,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1983: {'Captions available': 3,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 1,
#   'Shared/Split Screen': 0,
#   'Single-player': 1,
#   'Stats': 0,
#   'Steam Achievements': 1,
#   'Steam Cloud': 0,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1984: {'Captions available': 2,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 1,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 2,
#   'Shared/Split Screen': 0,
#   'Single-player': 2,
#   'Stats': 0,
#   'Steam Achievements': 2,
#   'Steam Cloud': 1,
#   'Steam Leaderboards': 1,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1985: {'Captions available': 2,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 0,
#   'Shared/Split Screen': 0,
#   'Single-player': 1,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Cloud': 0,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1986: {'Captions available': 1,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 0,
#   'Shared/Split Screen': 0,
#   'Single-player': 1,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Cloud': 1,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1987: {'Captions available': 5,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 0,
#   'Shared/Split Screen': 0,
#   'Single-player': 4,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Cloud': 1,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1988: {'Captions available': 1,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 0,
#   'Shared/Split Screen': 0,
#   'Single-player': 5,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Cloud': 1,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 1,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1989: {'Captions available': 2,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 0,
#   'Shared/Split Screen': 0,
#   'Single-player': 7,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Cloud': 0,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1990: {'Captions available': 2,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 1,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 3,
#   'Shared/Split Screen': 0,
#   'Single-player': 10,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Cloud': 2,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1991: {'Captions available': 4,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 1,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 1,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 5,
#   'Shared/Split Screen': 1,
#   'Single-player': 12,
#   'Stats': 0,
#   'Steam Achievements': 1,
#   'Steam Cloud': 0,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1992: {'Captions available': 2,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 1,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 1,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 4,
#   'Shared/Split Screen': 1,
#   'Single-player': 13,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Cloud': 2,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1993: {'Captions available': 8,
#   'Co-op': 1,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 1,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 1,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 8,
#   'Shared/Split Screen': 0,
#   'Single-player': 25,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Cloud': 2,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 2,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1994: {'Captions available': 3,
#   'Co-op': 1,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 1,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 2,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 15,
#   'Shared/Split Screen': 0,
#   'Single-player': 31,
#   'Stats': 0,
#   'Steam Achievements': 3,
#   'Steam Cloud': 6,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 4,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1995: {'Captions available': 2,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 1,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 1,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 4,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 4,
#   'Shared/Split Screen': 0,
#   'Single-player': 30,
#   'Stats': 0,
#   'Steam Achievements': 1,
#   'Steam Cloud': 6,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 3,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1996: {'Captions available': 3,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 1,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 9,
#   'Online Co-op': 0,
#   'Online Multi-Player': 1,
#   'Partial Controller Support': 3,
#   'Shared/Split Screen': 2,
#   'Single-player': 36,
#   'Stats': 0,
#   'Steam Achievements': 1,
#   'Steam Cloud': 4,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 6,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1997: {'Captions available': 3,
#   'Co-op': 2,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 2,
#   'Full controller support': 4,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 1,
#   'Local Co-op': 1,
#   'Local Multi-Player': 2,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 13,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 4,
#   'Shared/Split Screen': 1,
#   'Single-player': 39,
#   'Stats': 0,
#   'Steam Achievements': 5,
#   'Steam Cloud': 9,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 10,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1998: {'Captions available': 11,
#   'Co-op': 2,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 3,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 17,
#   'Online Co-op': 0,
#   'Online Multi-Player': 1,
#   'Partial Controller Support': 4,
#   'Shared/Split Screen': 1,
#   'Single-player': 50,
#   'Stats': 0,
#   'Steam Achievements': 1,
#   'Steam Cloud': 9,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 4,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 1},
#  1999: {'Captions available': 7,
#   'Co-op': 6,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 3,
#   'Full controller support': 1,
#   'Game demo': 0,
#   'In-App Purchases': 1,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 2,
#   'MMO': 1,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 13,
#   'Online Co-op': 0,
#   'Online Multi-Player': 2,
#   'Partial Controller Support': 3,
#   'Shared/Split Screen': 3,
#   'Single-player': 45,
#   'Stats': 0,
#   'Steam Achievements': 1,
#   'Steam Cloud': 10,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 7,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 1,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 2},
#  2000: {'Captions available': 5,
#   'Co-op': 1,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 1,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 1,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 13,
#   'Online Co-op': 0,
#   'Online Multi-Player': 1,
#   'Partial Controller Support': 0,
#   'Shared/Split Screen': 1,
#   'Single-player': 34,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Cloud': 4,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 2,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 2},
#  2001: {'Captions available': 13,
#   'Co-op': 6,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 1,
#   'Downloadable Content': 2,
#   'Full controller support': 1,
#   'Game demo': 0,
#   'In-App Purchases': 1,
#   'Includes Source SDK': 0,
#   'Includes level editor': 7,
#   'Local Co-op': 0,
#   'Local Multi-Player': 1,
#   'MMO': 4,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 25,
#   'Online Co-op': 1,
#   'Online Multi-Player': 5,
#   'Partial Controller Support': 0,
#   'Shared/Split Screen': 1,
#   'Single-player': 55,
#   'Stats': 1,
#   'Steam Achievements': 4,
#   'Steam Cloud': 12,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 6,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 1},
#  2002: {'Captions available': 7,
#   'Co-op': 2,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 3,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 1,
#   'Multi-player': 15,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 3,
#   'Shared/Split Screen': 2,
#   'Single-player': 40,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Cloud': 6,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 5,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  2003: {'Captions available': 12,
#   'Co-op': 2,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 1,
#   'Downloadable Content': 0,
#   'Full controller support': 2,
#   'Game demo': 1,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 3,
#   'Local Co-op': 0,
#   'Local Multi-Player': 2,
#   'MMO': 2,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 17,
#   'Online Co-op': 1,
#   'Online Multi-Player': 4,
#   'Partial Controller Support': 5,
#   'Shared/Split Screen': 0,
#   'Single-player': 72,
#   'Stats': 1,
#   'Steam Achievements': 5,
#   'Steam Cloud': 21,
#   'Steam Leaderboards': 1,
#   'Steam Trading Cards': 13,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 2,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 1},
#  2004: {'Captions available': 12,
#   'Co-op': 5,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 3,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 3,
#   'Includes level editor': 4,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 1,
#   'Mods (require HL2)': 0,
#   'Multi-player': 22,
#   'Online Co-op': 0,
#   'Online Multi-Player': 2,
#   'Partial Controller Support': 2,
#   'Shared/Split Screen': 1,
#   'Single-player': 61,
#   'Stats': 1,
#   'Steam Achievements': 5,
#   'Steam Cloud': 8,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 13,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 3},
#  2005: {'Captions available': 13,
#   'Co-op': 6,
#   'Commentary available': 1,
#   'Cross-Platform Multiplayer': 1,
#   'Downloadable Content': 4,
#   'Full controller support': 1,
#   'Game demo': 1,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 1,
#   'Includes level editor': 6,
#   'Local Co-op': 0,
#   'Local Multi-Player': 1,
#   'MMO': 1,
#   'Mods': 1,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 2,
#   'Multi-player': 27,
#   'Online Co-op': 1,
#   'Online Multi-Player': 1,
#   'Partial Controller Support': 11,
#   'Shared/Split Screen': 2,
#   'Single-player': 89,
#   'Stats': 3,
#   'Steam Achievements': 9,
#   'Steam Cloud': 24,
#   'Steam Leaderboards': 1,
#   'Steam Trading Cards': 13,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 2,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 1},
#  2006: {'Captions available': 13,
#   'Co-op': 8,
#   'Commentary available': 1,
#   'Cross-Platform Multiplayer': 5,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 2,
#   'In-App Purchases': 3,
#   'Includes Source SDK': 1,
#   'Includes level editor': 6,
#   'Local Co-op': 0,
#   'Local Multi-Player': 1,
#   'MMO': 4,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 49,
#   'Online Co-op': 0,
#   'Online Multi-Player': 3,
#   'Partial Controller Support': 9,
#   'Shared/Split Screen': 7,
#   'Single-player': 136,
#   'Stats': 4,
#   'Steam Achievements': 6,
#   'Steam Cloud': 17,
#   'Steam Leaderboards': 1,
#   'Steam Trading Cards': 20,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 2,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 5},
#  2007: {'Captions available': 21,
#   'Co-op': 8,
#   'Commentary available': 4,
#   'Cross-Platform Multiplayer': 2,
#   'Downloadable Content': 1,
#   'Full controller support': 2,
#   'Game demo': 0,
#   'In-App Purchases': 2,
#   'Includes Source SDK': 4,
#   'Includes level editor': 12,
#   'Local Co-op': 1,
#   'Local Multi-Player': 1,
#   'MMO': 4,
#   'Mods': 3,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 4,
#   'Multi-player': 41,
#   'Online Co-op': 1,
#   'Online Multi-Player': 2,
#   'Partial Controller Support': 17,
#   'Shared/Split Screen': 6,
#   'Single-player': 140,
#   'Stats': 2,
#   'Steam Achievements': 17,
#   'Steam Cloud': 21,
#   'Steam Leaderboards': 1,
#   'Steam Trading Cards': 17,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 3,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 4},
#  2008: {'Captions available': 18,
#   'Co-op': 12,
#   'Commentary available': 1,
#   'Cross-Platform Multiplayer': 4,
#   'Downloadable Content': 5,
#   'Full controller support': 11,
#   'Game demo': 2,
#   'In-App Purchases': 1,
#   'Includes Source SDK': 2,
#   'Includes level editor': 6,
#   'Local Co-op': 1,
#   'Local Multi-Player': 2,
#   'MMO': 5,
#   'Mods': 2,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 1,
#   'Multi-player': 47,
#   'Online Co-op': 1,
#   'Online Multi-Player': 6,
#   'Partial Controller Support': 24,
#   'Shared/Split Screen': 6,
#   'Single-player': 185,
#   'Stats': 2,
#   'Steam Achievements': 38,
#   'Steam Cloud': 21,
#   'Steam Leaderboards': 3,
#   'Steam Trading Cards': 19,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 1},
#  2009: {'Captions available': 18,
#   'Co-op': 28,
#   'Commentary available': 2,
#   'Cross-Platform Multiplayer': 6,
#   'Downloadable Content': 57,
#   'Full controller support': 39,
#   'Game demo': 5,
#   'In-App Purchases': 2,
#   'Includes Source SDK': 1,
#   'Includes level editor': 16,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 2,
#   'Mods': 4,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 2,
#   'Multi-player': 93,
#   'Online Co-op': 2,
#   'Online Multi-Player': 3,
#   'Partial Controller Support': 38,
#   'Shared/Split Screen': 7,
#   'Single-player': 312,
#   'Stats': 11,
#   'Steam Achievements': 88,
#   'Steam Cloud': 87,
#   'Steam Leaderboards': 45,
#   'Steam Trading Cards': 65,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 34,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 3},
#  2010: {'Captions available': 33,
#   'Co-op': 56,
#   'Commentary available': 1,
#   'Cross-Platform Multiplayer': 14,
#   'Downloadable Content': 105,
#   'Full controller support': 25,
#   'Game demo': 2,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 2,
#   'Includes level editor': 17,
#   'Local Co-op': 2,
#   'Local Multi-Player': 0,
#   'MMO': 3,
#   'Mods': 1,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 148,
#   'Online Co-op': 1,
#   'Online Multi-Player': 2,
#   'Partial Controller Support': 128,
#   'Shared/Split Screen': 33,
#   'Single-player': 371,
#   'Stats': 39,
#   'Steam Achievements': 154,
#   'Steam Cloud': 95,
#   'Steam Leaderboards': 75,
#   'Steam Trading Cards': 47,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 6,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 6},
#  2011: {'Captions available': 36,
#   'Co-op': 135,
#   'Commentary available': 3,
#   'Cross-Platform Multiplayer': 15,
#   'Downloadable Content': 228,
#   'Full controller support': 47,
#   'Game demo': 5,
#   'In-App Purchases': 2,
#   'Includes Source SDK': 1,
#   'Includes level editor': 17,
#   'Local Co-op': 5,
#   'Local Multi-Player': 4,
#   'MMO': 8,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 226,
#   'Online Co-op': 6,
#   'Online Multi-Player': 10,
#   'Partial Controller Support': 162,
#   'Shared/Split Screen': 58,
#   'Single-player': 513,
#   'Stats': 57,
#   'Steam Achievements': 247,
#   'Steam Cloud': 160,
#   'Steam Leaderboards': 127,
#   'Steam Trading Cards': 81,
#   'Steam Turn Notifications': 1,
#   'Steam Workshop': 9,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 19},
#  2012: {'Captions available': 45,
#   'Co-op': 249,
#   'Commentary available': 5,
#   'Cross-Platform Multiplayer': 45,
#   'Downloadable Content': 710,
#   'Full controller support': 114,
#   'Game demo': 11,
#   'In-App Purchases': 5,
#   'Includes Source SDK': 0,
#   'Includes level editor': 36,
#   'Local Co-op': 2,
#   'Local Multi-Player': 6,
#   'MMO': 18,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 444,
#   'Online Co-op': 5,
#   'Online Multi-Player': 13,
#   'Partial Controller Support': 299,
#   'Shared/Split Screen': 252,
#   'Single-player': 1043,
#   'Stats': 139,
#   'Steam Achievements': 551,
#   'Steam Cloud': 404,
#   'Steam Leaderboards': 282,
#   'Steam Trading Cards': 168,
#   'Steam Turn Notifications': 5,
#   'Steam Workshop': 22,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 79},
#  2013: {'Captions available': 101,
#   'Co-op': 374,
#   'Commentary available': 8,
#   'Cross-Platform Multiplayer': 109,
#   'Downloadable Content': 902,
#   'Full controller support': 473,
#   'Game demo': 17,
#   'In-App Purchases': 16,
#   'Includes Source SDK': 0,
#   'Includes level editor': 73,
#   'Local Co-op': 14,
#   'Local Multi-Player': 12,
#   'MMO': 39,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 646,
#   'Online Co-op': 18,
#   'Online Multi-Player': 24,
#   'Partial Controller Support': 324,
#   'Shared/Split Screen': 285,
#   'Single-player': 1378,
#   'Stats': 192,
#   'Steam Achievements': 966,
#   'Steam Cloud': 692,
#   'Steam Leaderboards': 505,
#   'Steam Trading Cards': 604,
#   'Steam Turn Notifications': 2,
#   'Steam Workshop': 84,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 79},
#  2014: {'Captions available': 175,
#   'Co-op': 425,
#   'Commentary available': 20,
#   'Cross-Platform Multiplayer': 250,
#   'Downloadable Content': 1346,
#   'Full controller support': 703,
#   'Game demo': 93,
#   'In-App Purchases': 13,
#   'Includes Source SDK': 11,
#   'Includes level editor': 165,
#   'Local Co-op': 13,
#   'Local Multi-Player': 21,
#   'MMO': 99,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 790,
#   'Online Co-op': 29,
#   'Online Multi-Player': 36,
#   'Partial Controller Support': 734,
#   'Shared/Split Screen': 484,
#   'Single-player': 2491,
#   'Stats': 217,
#   'Steam Achievements': 1726,
#   'Steam Cloud': 1220,
#   'Steam Leaderboards': 858,
#   'Steam Trading Cards': 1386,
#   'Steam Turn Notifications': 2,
#   'Steam Workshop': 306,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 70},
#  2015: {'Captions available': 259,
#   'Co-op': 660,
#   'Commentary available': 35,
#   'Cross-Platform Multiplayer': 381,
#   'Downloadable Content': 2156,
#   'Full controller support': 1487,
#   'Game demo': 181,
#   'In-App Purchases': 28,
#   'Includes Source SDK': 12,
#   'Includes level editor': 280,
#   'Local Co-op': 52,
#   'Local Multi-Player': 52,
#   'MMO': 147,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 1315,
#   'Online Co-op': 53,
#   'Online Multi-Player': 91,
#   'Partial Controller Support': 1114,
#   'Shared/Split Screen': 728,
#   'Single-player': 4354,
#   'Stats': 414,
#   'Steam Achievements': 2870,
#   'Steam Cloud': 1888,
#   'Steam Leaderboards': 1165,
#   'Steam Trading Cards': 2521,
#   'Steam Turn Notifications': 17,
#   'Steam Workshop': 363,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 55},
#  2016: {'Captions available': 300,
#   'Co-op': 900,
#   'Commentary available': 59,
#   'Cross-Platform Multiplayer': 674,
#   'Downloadable Content': 3121,
#   'Full controller support': 1900,
#   'Game demo': 27,
#   'In-App Purchases': 256,
#   'Includes Source SDK': 12,
#   'Includes level editor': 336,
#   'Local Co-op': 188,
#   'Local Multi-Player': 293,
#   'MMO': 275,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 1770,
#   'Online Co-op': 208,
#   'Online Multi-Player': 538,
#   'Partial Controller Support': 1456,
#   'Shared/Split Screen': 871,
#   'Single-player': 5926,
#   'Stats': 489,
#   'Steam Achievements': 3962,
#   'Steam Cloud': 2193,
#   'Steam Leaderboards': 1258,
#   'Steam Trading Cards': 3571,
#   'Steam Turn Notifications': 33,
#   'Steam Workshop': 451,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 38},
#  2017: {'Captions available': 448,
#   'Co-op': 1310,
#   'Commentary available': 48,
#   'Cross-Platform Multiplayer': 933,
#   'Downloadable Content': 3988,
#   'Full controller support': 2209,
#   'Game demo': 9,
#   'In-App Purchases': 572,
#   'Includes Source SDK': 9,
#   'Includes level editor': 337,
#   'Local Co-op': 417,
#   'Local Multi-Player': 721,
#   'MMO': 312,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 2206,
#   'Online Co-op': 582,
#   'Online Multi-Player': 1379,
#   'Partial Controller Support': 1941,
#   'Shared/Split Screen': 1122,
#   'Single-player': 7990,
#   'Stats': 607,
#   'Steam Achievements': 5028,
#   'Steam Cloud': 2754,
#   'Steam Leaderboards': 1407,
#   'Steam Trading Cards': 3317,
#   'Steam Turn Notifications': 28,
#   'Steam Workshop': 530,
#   'SteamVR Collectibles': 1,
#   'Valve Anti-Cheat enabled': 90},
#  2018: {'Captions available': 6,
#   'Co-op': 3,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 9,
#   'Downloadable Content': 15,
#   'Full controller support': 44,
#   'Game demo': 0,
#   'In-App Purchases': 12,
#   'Includes Source SDK': 0,
#   'Includes level editor': 4,
#   'Local Co-op': 5,
#   'Local Multi-Player': 8,
#   'MMO': 1,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 21,
#   'Online Co-op': 2,
#   'Online Multi-Player': 18,
#   'Partial Controller Support': 29,
#   'Shared/Split Screen': 12,
#   'Single-player': 147,
#   'Stats': 5,
#   'Steam Achievements': 68,
#   'Steam Cloud': 30,
#   'Steam Leaderboards': 13,
#   'Steam Trading Cards': 23,
#   'Steam Turn Notifications': 2,
#   'Steam Workshop': 3,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  2019: {'Captions available': 0,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 2,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 0,
#   'Shared/Split Screen': 0,
#   'Single-player': 4,
#   'Stats': 0,
#   'Steam Achievements': 2,
#   'Steam Cloud': 1,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  2021: {'Captions available': 0,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 1,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 0,
#   'Shared/Split Screen': 0,
#   'Single-player': 1,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Cloud': 0,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0}}

# %% [markdown]
# Sort by values.

# %%
specsEndpointDict_sorted = {}
for y in specsEndpointDict.keys():
    specs = specsEndpointDict[y]
    specs_sorted = {k: v for k, v in sorted(specs.items(), key=lambda item: item[1], reverse=True)}
    specsEndpointDict_sorted[y] = specs_sorted

specsEndpointDict_sorted
# Out:
# {1970: {'Captions available': 2,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 0,
#   'Shared/Split Screen': 0,
#   'Single-player': 0,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Cloud': 0,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1975: {'Captions available': 1,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 0,
#   'Shared/Split Screen': 0,
#   'Single-player': 0,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Cloud': 0,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1980: {'Captions available': 1,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 0,
#   'Shared/Split Screen': 0,
#   'Single-player': 0,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Cloud': 0,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1981: {'Captions available': 2,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 0,
#   'Shared/Split Screen': 0,
#   'Single-player': 0,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Cloud': 0,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1982: {'Captions available': 3,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 0,
#   'Shared/Split Screen': 0,
#   'Single-player': 0,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Cloud': 0,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1983: {'Captions available': 3,
#   'Partial Controller Support': 1,
#   'Single-player': 1,
#   'Steam Achievements': 1,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Shared/Split Screen': 0,
#   'Stats': 0,
#   'Steam Cloud': 0,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1984: {'Captions available': 2,
#   'Partial Controller Support': 2,
#   'Single-player': 2,
#   'Steam Achievements': 2,
#   'Local Co-op': 1,
#   'Steam Cloud': 1,
#   'Steam Leaderboards': 1,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Shared/Split Screen': 0,
#   'Stats': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1985: {'Captions available': 2,
#   'Single-player': 1,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 0,
#   'Shared/Split Screen': 0,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Cloud': 0,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1986: {'Captions available': 1,
#   'Single-player': 1,
#   'Steam Cloud': 1,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 0,
#   'Shared/Split Screen': 0,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1987: {'Captions available': 5,
#   'Single-player': 4,
#   'Steam Cloud': 1,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 0,
#   'Shared/Split Screen': 0,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1988: {'Single-player': 5,
#   'Captions available': 1,
#   'Steam Cloud': 1,
#   'Steam Trading Cards': 1,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 0,
#   'Shared/Split Screen': 0,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Leaderboards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1989: {'Single-player': 7,
#   'Captions available': 2,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 0,
#   'Shared/Split Screen': 0,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Cloud': 0,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1990: {'Single-player': 10,
#   'Partial Controller Support': 3,
#   'Captions available': 2,
#   'Steam Cloud': 2,
#   'Multi-player': 1,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Shared/Split Screen': 0,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1991: {'Single-player': 12,
#   'Partial Controller Support': 5,
#   'Captions available': 4,
#   'Local Multi-Player': 1,
#   'Multi-player': 1,
#   'Shared/Split Screen': 1,
#   'Steam Achievements': 1,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Stats': 0,
#   'Steam Cloud': 0,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1992: {'Single-player': 13,
#   'Partial Controller Support': 4,
#   'Captions available': 2,
#   'Steam Cloud': 2,
#   'Local Co-op': 1,
#   'Multi-player': 1,
#   'Shared/Split Screen': 1,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1993: {'Single-player': 25,
#   'Captions available': 8,
#   'Partial Controller Support': 8,
#   'Steam Cloud': 2,
#   'Steam Trading Cards': 2,
#   'Co-op': 1,
#   'Local Multi-Player': 1,
#   'Multi-player': 1,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Shared/Split Screen': 0,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Leaderboards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1994: {'Single-player': 31,
#   'Partial Controller Support': 15,
#   'Steam Cloud': 6,
#   'Steam Trading Cards': 4,
#   'Captions available': 3,
#   'Steam Achievements': 3,
#   'Multi-player': 2,
#   'Co-op': 1,
#   'Full controller support': 1,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Shared/Split Screen': 0,
#   'Stats': 0,
#   'Steam Leaderboards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1995: {'Single-player': 30,
#   'Steam Cloud': 6,
#   'Multi-player': 4,
#   'Partial Controller Support': 4,
#   'Steam Trading Cards': 3,
#   'Captions available': 2,
#   'Full controller support': 1,
#   'Local Multi-Player': 1,
#   'Steam Achievements': 1,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Shared/Split Screen': 0,
#   'Stats': 0,
#   'Steam Leaderboards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1996: {'Single-player': 36,
#   'Multi-player': 9,
#   'Steam Trading Cards': 6,
#   'Steam Cloud': 4,
#   'Captions available': 3,
#   'Partial Controller Support': 3,
#   'Shared/Split Screen': 2,
#   'Downloadable Content': 1,
#   'Online Multi-Player': 1,
#   'Steam Achievements': 1,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Online Co-op': 0,
#   'Stats': 0,
#   'Steam Leaderboards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1997: {'Single-player': 39,
#   'Multi-player': 13,
#   'Steam Trading Cards': 10,
#   'Steam Cloud': 9,
#   'Steam Achievements': 5,
#   'Full controller support': 4,
#   'Partial Controller Support': 4,
#   'Captions available': 3,
#   'Co-op': 2,
#   'Downloadable Content': 2,
#   'Local Multi-Player': 2,
#   'Includes level editor': 1,
#   'Local Co-op': 1,
#   'Shared/Split Screen': 1,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Stats': 0,
#   'Steam Leaderboards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1998: {'Single-player': 50,
#   'Multi-player': 17,
#   'Captions available': 11,
#   'Steam Cloud': 9,
#   'Partial Controller Support': 4,
#   'Steam Trading Cards': 4,
#   'Local Multi-Player': 3,
#   'Co-op': 2,
#   'Online Multi-Player': 1,
#   'Shared/Split Screen': 1,
#   'Steam Achievements': 1,
#   'Valve Anti-Cheat enabled': 1,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Online Co-op': 0,
#   'Stats': 0,
#   'Steam Leaderboards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0},
#  1999: {'Single-player': 45,
#   'Multi-player': 13,
#   'Steam Cloud': 10,
#   'Captions available': 7,
#   'Steam Trading Cards': 7,
#   'Co-op': 6,
#   'Downloadable Content': 3,
#   'Partial Controller Support': 3,
#   'Shared/Split Screen': 3,
#   'Local Multi-Player': 2,
#   'Online Multi-Player': 2,
#   'Valve Anti-Cheat enabled': 2,
#   'Full controller support': 1,
#   'In-App Purchases': 1,
#   'MMO': 1,
#   'Steam Achievements': 1,
#   'Steam Workshop': 1,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Game demo': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Online Co-op': 0,
#   'Stats': 0,
#   'Steam Leaderboards': 0,
#   'Steam Turn Notifications': 0,
#   'SteamVR Collectibles': 0},
#  2000: {'Single-player': 34,
#   'Multi-player': 13,
#   'Captions available': 5,
#   'Steam Cloud': 4,
#   'Steam Trading Cards': 2,
#   'Valve Anti-Cheat enabled': 2,
#   'Co-op': 1,
#   'Cross-Platform Multiplayer': 1,
#   'Includes level editor': 1,
#   'Online Multi-Player': 1,
#   'Shared/Split Screen': 1,
#   'Commentary available': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Online Co-op': 0,
#   'Partial Controller Support': 0,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Leaderboards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0},
#  2001: {'Single-player': 55,
#   'Multi-player': 25,
#   'Captions available': 13,
#   'Steam Cloud': 12,
#   'Includes level editor': 7,
#   'Co-op': 6,
#   'Steam Trading Cards': 6,
#   'Online Multi-Player': 5,
#   'MMO': 4,
#   'Steam Achievements': 4,
#   'Downloadable Content': 2,
#   'Cross-Platform Multiplayer': 1,
#   'Full controller support': 1,
#   'In-App Purchases': 1,
#   'Local Multi-Player': 1,
#   'Online Co-op': 1,
#   'Shared/Split Screen': 1,
#   'Stats': 1,
#   'Valve Anti-Cheat enabled': 1,
#   'Commentary available': 0,
#   'Game demo': 0,
#   'Includes Source SDK': 0,
#   'Local Co-op': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Partial Controller Support': 0,
#   'Steam Leaderboards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0},
#  2002: {'Single-player': 40,
#   'Multi-player': 15,
#   'Captions available': 7,
#   'Steam Cloud': 6,
#   'Steam Trading Cards': 5,
#   'Includes level editor': 3,
#   'Partial Controller Support': 3,
#   'Co-op': 2,
#   'Shared/Split Screen': 2,
#   'Mods (require HL2)': 1,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Leaderboards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  2003: {'Single-player': 72,
#   'Steam Cloud': 21,
#   'Multi-player': 17,
#   'Steam Trading Cards': 13,
#   'Captions available': 12,
#   'Partial Controller Support': 5,
#   'Steam Achievements': 5,
#   'Online Multi-Player': 4,
#   'Includes level editor': 3,
#   'Co-op': 2,
#   'Full controller support': 2,
#   'Local Multi-Player': 2,
#   'MMO': 2,
#   'Steam Workshop': 2,
#   'Cross-Platform Multiplayer': 1,
#   'Game demo': 1,
#   'Online Co-op': 1,
#   'Stats': 1,
#   'Steam Leaderboards': 1,
#   'Valve Anti-Cheat enabled': 1,
#   'Commentary available': 0,
#   'Downloadable Content': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Local Co-op': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Shared/Split Screen': 0,
#   'Steam Turn Notifications': 0,
#   'SteamVR Collectibles': 0},
#  2004: {'Single-player': 61,
#   'Multi-player': 22,
#   'Steam Trading Cards': 13,
#   'Captions available': 12,
#   'Steam Cloud': 8,
#   'Co-op': 5,
#   'Steam Achievements': 5,
#   'Includes level editor': 4,
#   'Cross-Platform Multiplayer': 3,
#   'Includes Source SDK': 3,
#   'Valve Anti-Cheat enabled': 3,
#   'Online Multi-Player': 2,
#   'Partial Controller Support': 2,
#   'Mods (require HL1)': 1,
#   'Shared/Split Screen': 1,
#   'Stats': 1,
#   'Commentary available': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL2)': 0,
#   'Online Co-op': 0,
#   'Steam Leaderboards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0},
#  2005: {'Single-player': 89,
#   'Multi-player': 27,
#   'Steam Cloud': 24,
#   'Captions available': 13,
#   'Steam Trading Cards': 13,
#   'Partial Controller Support': 11,
#   'Steam Achievements': 9,
#   'Co-op': 6,
#   'Includes level editor': 6,
#   'Downloadable Content': 4,
#   'Stats': 3,
#   'Mods (require HL2)': 2,
#   'Shared/Split Screen': 2,
#   'Steam Workshop': 2,
#   'Commentary available': 1,
#   'Cross-Platform Multiplayer': 1,
#   'Full controller support': 1,
#   'Game demo': 1,
#   'Includes Source SDK': 1,
#   'Local Multi-Player': 1,
#   'MMO': 1,
#   'Mods': 1,
#   'Online Co-op': 1,
#   'Online Multi-Player': 1,
#   'Steam Leaderboards': 1,
#   'Valve Anti-Cheat enabled': 1,
#   'In-App Purchases': 0,
#   'Local Co-op': 0,
#   'Mods (require HL1)': 0,
#   'Steam Turn Notifications': 0,
#   'SteamVR Collectibles': 0},
#  2006: {'Single-player': 136,
#   'Multi-player': 49,
#   'Steam Trading Cards': 20,
#   'Steam Cloud': 17,
#   'Captions available': 13,
#   'Partial Controller Support': 9,
#   'Co-op': 8,
#   'Shared/Split Screen': 7,
#   'Includes level editor': 6,
#   'Steam Achievements': 6,
#   'Cross-Platform Multiplayer': 5,
#   'Valve Anti-Cheat enabled': 5,
#   'MMO': 4,
#   'Stats': 4,
#   'In-App Purchases': 3,
#   'Online Multi-Player': 3,
#   'Game demo': 2,
#   'Steam Workshop': 2,
#   'Commentary available': 1,
#   'Includes Source SDK': 1,
#   'Local Multi-Player': 1,
#   'Steam Leaderboards': 1,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Local Co-op': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Online Co-op': 0,
#   'Steam Turn Notifications': 0,
#   'SteamVR Collectibles': 0},
#  2007: {'Single-player': 140,
#   'Multi-player': 41,
#   'Captions available': 21,
#   'Steam Cloud': 21,
#   'Partial Controller Support': 17,
#   'Steam Achievements': 17,
#   'Steam Trading Cards': 17,
#   'Includes level editor': 12,
#   'Co-op': 8,
#   'Shared/Split Screen': 6,
#   'Commentary available': 4,
#   'Includes Source SDK': 4,
#   'MMO': 4,
#   'Mods (require HL2)': 4,
#   'Valve Anti-Cheat enabled': 4,
#   'Mods': 3,
#   'Steam Workshop': 3,
#   'Cross-Platform Multiplayer': 2,
#   'Full controller support': 2,
#   'In-App Purchases': 2,
#   'Online Multi-Player': 2,
#   'Stats': 2,
#   'Downloadable Content': 1,
#   'Local Co-op': 1,
#   'Local Multi-Player': 1,
#   'Online Co-op': 1,
#   'Steam Leaderboards': 1,
#   'Game demo': 0,
#   'Mods (require HL1)': 0,
#   'Steam Turn Notifications': 0,
#   'SteamVR Collectibles': 0},
#  2008: {'Single-player': 185,
#   'Multi-player': 47,
#   'Steam Achievements': 38,
#   'Partial Controller Support': 24,
#   'Steam Cloud': 21,
#   'Steam Trading Cards': 19,
#   'Captions available': 18,
#   'Co-op': 12,
#   'Full controller support': 11,
#   'Includes level editor': 6,
#   'Online Multi-Player': 6,
#   'Shared/Split Screen': 6,
#   'Downloadable Content': 5,
#   'MMO': 5,
#   'Cross-Platform Multiplayer': 4,
#   'Steam Leaderboards': 3,
#   'Game demo': 2,
#   'Includes Source SDK': 2,
#   'Local Multi-Player': 2,
#   'Mods': 2,
#   'Stats': 2,
#   'Commentary available': 1,
#   'In-App Purchases': 1,
#   'Local Co-op': 1,
#   'Mods (require HL2)': 1,
#   'Online Co-op': 1,
#   'Valve Anti-Cheat enabled': 1,
#   'Mods (require HL1)': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0},
#  2009: {'Single-player': 312,
#   'Multi-player': 93,
#   'Steam Achievements': 88,
#   'Steam Cloud': 87,
#   'Steam Trading Cards': 65,
#   'Downloadable Content': 57,
#   'Steam Leaderboards': 45,
#   'Full controller support': 39,
#   'Partial Controller Support': 38,
#   'Steam Workshop': 34,
#   'Co-op': 28,
#   'Captions available': 18,
#   'Includes level editor': 16,
#   'Stats': 11,
#   'Shared/Split Screen': 7,
#   'Cross-Platform Multiplayer': 6,
#   'Game demo': 5,
#   'Mods': 4,
#   'Online Multi-Player': 3,
#   'Valve Anti-Cheat enabled': 3,
#   'Commentary available': 2,
#   'In-App Purchases': 2,
#   'MMO': 2,
#   'Mods (require HL2)': 2,
#   'Online Co-op': 2,
#   'Includes Source SDK': 1,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'Mods (require HL1)': 0,
#   'Steam Turn Notifications': 0,
#   'SteamVR Collectibles': 0},
#  2010: {'Single-player': 371,
#   'Steam Achievements': 154,
#   'Multi-player': 148,
#   'Partial Controller Support': 128,
#   'Downloadable Content': 105,
#   'Steam Cloud': 95,
#   'Steam Leaderboards': 75,
#   'Co-op': 56,
#   'Steam Trading Cards': 47,
#   'Stats': 39,
#   'Captions available': 33,
#   'Shared/Split Screen': 33,
#   'Full controller support': 25,
#   'Includes level editor': 17,
#   'Cross-Platform Multiplayer': 14,
#   'Steam Workshop': 6,
#   'Valve Anti-Cheat enabled': 6,
#   'MMO': 3,
#   'Game demo': 2,
#   'Includes Source SDK': 2,
#   'Local Co-op': 2,
#   'Online Multi-Player': 2,
#   'Commentary available': 1,
#   'Mods': 1,
#   'Online Co-op': 1,
#   'In-App Purchases': 0,
#   'Local Multi-Player': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Steam Turn Notifications': 0,
#   'SteamVR Collectibles': 0},
#  2011: {'Single-player': 513,
#   'Steam Achievements': 247,
#   'Downloadable Content': 228,
#   'Multi-player': 226,
#   'Partial Controller Support': 162,
#   'Steam Cloud': 160,
#   'Co-op': 135,
#   'Steam Leaderboards': 127,
#   'Steam Trading Cards': 81,
#   'Shared/Split Screen': 58,
#   'Stats': 57,
#   'Full controller support': 47,
#   'Captions available': 36,
#   'Valve Anti-Cheat enabled': 19,
#   'Includes level editor': 17,
#   'Cross-Platform Multiplayer': 15,
#   'Online Multi-Player': 10,
#   'Steam Workshop': 9,
#   'MMO': 8,
#   'Online Co-op': 6,
#   'Game demo': 5,
#   'Local Co-op': 5,
#   'Local Multi-Player': 4,
#   'Commentary available': 3,
#   'In-App Purchases': 2,
#   'Includes Source SDK': 1,
#   'Steam Turn Notifications': 1,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'SteamVR Collectibles': 0},
#  2012: {'Single-player': 1043,
#   'Downloadable Content': 710,
#   'Steam Achievements': 551,
#   'Multi-player': 444,
#   'Steam Cloud': 404,
#   'Partial Controller Support': 299,
#   'Steam Leaderboards': 282,
#   'Shared/Split Screen': 252,
#   'Co-op': 249,
#   'Steam Trading Cards': 168,
#   'Stats': 139,
#   'Full controller support': 114,
#   'Valve Anti-Cheat enabled': 79,
#   'Captions available': 45,
#   'Cross-Platform Multiplayer': 45,
#   'Includes level editor': 36,
#   'Steam Workshop': 22,
#   'MMO': 18,
#   'Online Multi-Player': 13,
#   'Game demo': 11,
#   'Local Multi-Player': 6,
#   'Commentary available': 5,
#   'In-App Purchases': 5,
#   'Online Co-op': 5,
#   'Steam Turn Notifications': 5,
#   'Local Co-op': 2,
#   'Includes Source SDK': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'SteamVR Collectibles': 0},
#  2013: {'Single-player': 1378,
#   'Steam Achievements': 966,
#   'Downloadable Content': 902,
#   'Steam Cloud': 692,
#   'Multi-player': 646,
#   'Steam Trading Cards': 604,
#   'Steam Leaderboards': 505,
#   'Full controller support': 473,
#   'Co-op': 374,
#   'Partial Controller Support': 324,
#   'Shared/Split Screen': 285,
#   'Stats': 192,
#   'Cross-Platform Multiplayer': 109,
#   'Captions available': 101,
#   'Steam Workshop': 84,
#   'Valve Anti-Cheat enabled': 79,
#   'Includes level editor': 73,
#   'MMO': 39,
#   'Online Multi-Player': 24,
#   'Online Co-op': 18,
#   'Game demo': 17,
#   'In-App Purchases': 16,
#   'Local Co-op': 14,
#   'Local Multi-Player': 12,
#   'Commentary available': 8,
#   'Steam Turn Notifications': 2,
#   'Includes Source SDK': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'SteamVR Collectibles': 0},
#  2014: {'Single-player': 2491,
#   'Steam Achievements': 1726,
#   'Steam Trading Cards': 1386,
#   'Downloadable Content': 1346,
#   'Steam Cloud': 1220,
#   'Steam Leaderboards': 858,
#   'Multi-player': 790,
#   'Partial Controller Support': 734,
#   'Full controller support': 703,
#   'Shared/Split Screen': 484,
#   'Co-op': 425,
#   'Steam Workshop': 306,
#   'Cross-Platform Multiplayer': 250,
#   'Stats': 217,
#   'Captions available': 175,
#   'Includes level editor': 165,
#   'MMO': 99,
#   'Game demo': 93,
#   'Valve Anti-Cheat enabled': 70,
#   'Online Multi-Player': 36,
#   'Online Co-op': 29,
#   'Local Multi-Player': 21,
#   'Commentary available': 20,
#   'In-App Purchases': 13,
#   'Local Co-op': 13,
#   'Includes Source SDK': 11,
#   'Steam Turn Notifications': 2,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'SteamVR Collectibles': 0},
#  2015: {'Single-player': 4354,
#   'Steam Achievements': 2870,
#   'Steam Trading Cards': 2521,
#   'Downloadable Content': 2156,
#   'Steam Cloud': 1888,
#   'Full controller support': 1487,
#   'Multi-player': 1315,
#   'Steam Leaderboards': 1165,
#   'Partial Controller Support': 1114,
#   'Shared/Split Screen': 728,
#   'Co-op': 660,
#   'Stats': 414,
#   'Cross-Platform Multiplayer': 381,
#   'Steam Workshop': 363,
#   'Includes level editor': 280,
#   'Captions available': 259,
#   'Game demo': 181,
#   'MMO': 147,
#   'Online Multi-Player': 91,
#   'Valve Anti-Cheat enabled': 55,
#   'Online Co-op': 53,
#   'Local Co-op': 52,
#   'Local Multi-Player': 52,
#   'Commentary available': 35,
#   'In-App Purchases': 28,
#   'Steam Turn Notifications': 17,
#   'Includes Source SDK': 12,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'SteamVR Collectibles': 0},
#  2016: {'Single-player': 5926,
#   'Steam Achievements': 3962,
#   'Steam Trading Cards': 3571,
#   'Downloadable Content': 3121,
#   'Steam Cloud': 2193,
#   'Full controller support': 1900,
#   'Multi-player': 1770,
#   'Partial Controller Support': 1456,
#   'Steam Leaderboards': 1258,
#   'Co-op': 900,
#   'Shared/Split Screen': 871,
#   'Cross-Platform Multiplayer': 674,
#   'Online Multi-Player': 538,
#   'Stats': 489,
#   'Steam Workshop': 451,
#   'Includes level editor': 336,
#   'Captions available': 300,
#   'Local Multi-Player': 293,
#   'MMO': 275,
#   'In-App Purchases': 256,
#   'Online Co-op': 208,
#   'Local Co-op': 188,
#   'Commentary available': 59,
#   'Valve Anti-Cheat enabled': 38,
#   'Steam Turn Notifications': 33,
#   'Game demo': 27,
#   'Includes Source SDK': 12,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'SteamVR Collectibles': 0},
#  2017: {'Single-player': 7990,
#   'Steam Achievements': 5028,
#   'Downloadable Content': 3988,
#   'Steam Trading Cards': 3317,
#   'Steam Cloud': 2754,
#   'Full controller support': 2209,
#   'Multi-player': 2206,
#   'Partial Controller Support': 1941,
#   'Steam Leaderboards': 1407,
#   'Online Multi-Player': 1379,
#   'Co-op': 1310,
#   'Shared/Split Screen': 1122,
#   'Cross-Platform Multiplayer': 933,
#   'Local Multi-Player': 721,
#   'Stats': 607,
#   'Online Co-op': 582,
#   'In-App Purchases': 572,
#   'Steam Workshop': 530,
#   'Captions available': 448,
#   'Local Co-op': 417,
#   'Includes level editor': 337,
#   'MMO': 312,
#   'Valve Anti-Cheat enabled': 90,
#   'Commentary available': 48,
#   'Steam Turn Notifications': 28,
#   'Game demo': 9,
#   'Includes Source SDK': 9,
#   'SteamVR Collectibles': 1,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0},
#  2018: {'Single-player': 147,
#   'Steam Achievements': 68,
#   'Full controller support': 44,
#   'Steam Cloud': 30,
#   'Partial Controller Support': 29,
#   'Steam Trading Cards': 23,
#   'Multi-player': 21,
#   'Online Multi-Player': 18,
#   'Downloadable Content': 15,
#   'Steam Leaderboards': 13,
#   'In-App Purchases': 12,
#   'Shared/Split Screen': 12,
#   'Cross-Platform Multiplayer': 9,
#   'Local Multi-Player': 8,
#   'Captions available': 6,
#   'Local Co-op': 5,
#   'Stats': 5,
#   'Includes level editor': 4,
#   'Co-op': 3,
#   'Steam Workshop': 3,
#   'Online Co-op': 2,
#   'Steam Turn Notifications': 2,
#   'MMO': 1,
#   'Commentary available': 0,
#   'Game demo': 0,
#   'Includes Source SDK': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  2019: {'Single-player': 4,
#   'Full controller support': 2,
#   'Steam Achievements': 2,
#   'Steam Cloud': 1,
#   'Captions available': 0,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 0,
#   'Shared/Split Screen': 0,
#   'Stats': 0,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  2021: {'Downloadable Content': 1,
#   'Single-player': 1,
#   'Captions available': 0,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 0,
#   'Shared/Split Screen': 0,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Cloud': 0,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0}}

# %%
with open("datasets/steam_games_endpoint_3_specs.json", "w") as outfile:
    json.dump(specsEndpointDict_sorted, outfile)

# %% [markdown]
# **TEST**

# %%
def specs( Year: str ):
    """
    Se ingresa un año y devuelve un diccionario con los 5 specs que más se repiten en el mismo en el orden correspondiente.
    """
    # Read data
    with open("datasets/steam_games_endpoint_3_specs.json") as json_file:
        specs_dict = json.load(json_file)

    # TODO Add validation

    # Since data is already sorted, get the first 5 as top 5.
    top5 = dict(list(specs_dict[Year].items())[0:5])
    return top5

specs('2018')
# Out:
# {'Single-player': 147,
#  'Steam Achievements': 68,
#  'Full controller support': 44,
#  'Steam Cloud': 30,
#  'Partial Controller Support': 29}

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## CREATE API FUNCTIONS (Testing)
